# %% [markdown]
# ## data gen

# %%
import os
import json
from pydantic import BaseModel
import transformers
import torch
import logging
from tqdm import tqdm
from time import sleep
import csv
import pandas as pd
# Set up the logger
logging.basicConfig(
    level=logging.INFO,  # Change to DEBUG for more detailed logs
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[
        logging.FileHandler("process.log"),  # Logs will be saved in this file
        logging.StreamHandler()  # Logs will also be printed to the console
    ]
)
logger = logging.getLogger(__name__)

# Define schema with Pydantic
class Question(BaseModel):
    """Structure for each generated question."""
    text: str

class QuestionSet(BaseModel):
    """Set of generated questions."""
    questions: list[Question]
    
# Define schema with Pydantic
class Step(BaseModel):
    """Required steps to answer the question."""
    explanation: str

class ChainOfThought(BaseModel):
    """Final answer with the list of steps."""
    steps: list[Step]
    final_answer: str
    
# Model setup
MODEL_ID = "./Meta-Llama-3.1-8B-Instruct"

pipeline = transformers.pipeline(
    "text-generation",
    model=MODEL_ID,
    model_kwargs={"torch_dtype": torch.bfloat16},
    device_map="cuda",
    pad_token_id=50256,
)

# JSON Schema
q_schema = json.dumps(QuestionSet.model_json_schema())
a_schema = json.dumps(ChainOfThought.model_json_schema())

# Define schema with Pydantic
class Question(BaseModel):
    """Structure for each generated question."""
    text: str

class QuestionSet(BaseModel):
    """Set of generated questions."""
    questions: list[Question]
    
# Generate content
def generate_content(prompt: str, max_new_tokens: int) -> str:
    outputs = pipeline(
        prompt,
        max_new_tokens=max_new_tokens,
        return_full_text=False,
    )
    return outputs[0]["generated_text"]


def Q_gen_template_prompt(context, num_questions, schema):
    system_prompt = (
        "You are a bot that generates specific and answerable questions based on the provided context. "
        "You must respond with a JSON object following the given schema without any additional information."
    )
    
    # Construct prompt
    prompt = f"""
    <|begin_of_text|><|start_header_id|>system<|end_header_id|>
    {system_prompt}<|eot_id|>
    <|start_header_id|>user<|end_header_id|>
    Make sure to return ONLY an instance of the JSON, NOT the schema itself. Do not add any additional information.
    JSON schema:
    {schema}
    
    Task: Generate {num_questions} example questions that could be answered using the following context. 
    Make the questions specific and answerable from the text.
    
    Context: {context}
    
    Questions:<|eot_id|><|start_header_id|>assistant<|end_header_id|>
    """
    return prompt

def A_gen_template_prompt(question,chunk,schema):
    # System and task setup
    system_prompt = (
        "You are a bot that ONLY responds with an instance of JSON without any additional information. "
        "You have access to a JSON schema, which will determine how the JSON should be structured."
    )
    
    # Construct the task-specific prompt
    task = f"""
    Question: {question}
    Context: {chunk}
    
    Answer this question using the information given in the context above. Here are things to pay attention to:
    - First provide step-by-step reasoning on how to answer the question.
    - In the reasoning, if you need to copy paste some sentences from the context, include them in ##begin_quote## and ##end_quote##. This would mean that things outside of ##begin_quote## and ##end_quote## are not directly copy paste from the context.
    - End your response with final answer in the form <ANSWER>: $answer, the answer should be succinct.
    """
    
    prompt = f"""
    <|begin_of_text|><|start_header_id|>system<|end_header_id|>
    {system_prompt}<|eot_id|>
    <|start_header_id|>user<|end_header_id|>
    Make sure to return ONLY an instance of the JSON, NOT the schema itself. Do not add any additional information.
    JSON schema:
    {schema}
    
    Task: {task}<|eot_id|><|start_header_id|>assistant<|end_header_id|>
    """
    return prompt

# Define the CSV file header and filename
CSV_FILENAME = "craft2.csv"
CSV_HEADERS = ["question", "context", "steps", "final_ans"]

# Ensure the file is initialized with headers if not already created
try:
    with open(CSV_FILENAME, "x", newline="", encoding="utf-8") as f:
        writer = csv.DictWriter(f, fieldnames=CSV_HEADERS)
        writer.writeheader()
except FileExistsError:
    pass  # File already exists; do not overwrite

def process_and_save_answer(question, chunk, steps, answer, csv_filename, csv_headers):
    """
    Processes a successful answer and appends it to a CSV file.

    Parameters:
        question (object): An object containing the question text.
        chunk (str): The context used for generating the answer.
        steps(list): Cot.
        answer (object): An object containing the answer steps and final answer.
        csv_filename (str): The name of the CSV file to append data to.
        csv_headers (list): The headers for the CSV file.

    Returns:
        None
    """
    # Prepare data to append
    temp = {
        "question": question,
        "context": chunk,
        "steps": steps,
        "final_ans": answer,
    }

    # Append data to the CSV file
    try:
        with open(csv_filename, "a", newline="", encoding="utf-8") as f:
            writer = csv.DictWriter(f, fieldnames=csv_headers)
            writer.writerow(temp)
        logger.info("Question and answer successfully appended to the CSV file.")
    except Exception as e:
        logger.error(f"Error writing to CSV file: {e}", exc_info=True)

def run(chunks, num_questions):
    for chunk in tqdm(chunks, desc="complete chunks:"):
        # Retry mechanism for generating questions
        # for attempt in range(3):  # Retry up to 3 times
        attempt = -1
        while True:
            attempt += 1
            try:
                logger.info("Generating questions for the current chunk...")
                Q_response = generate_content(Q_gen_template_prompt(chunk, num_questions, q_schema), 512)
                logger.debug(f"Q_response: {Q_response}")
                questions = QuestionSet.model_validate_json(Q_response)
                logger.debug(f"{len(questions.questions)} questions generated successfully.")
                break  # Exit retry loop if successful
            except Exception as e:
                logger.error(f"Error generating or validating questions (attempt {attempt + 1}/3): {e}", exc_info=True)
        #         if attempt == 2:  # If it's the last attempt, skip to the next chunk
        #             logger.error("Maximum retries reached for questions. Skipping this chunk.")
        #             continue
        # else:
        #     # If all retries fail, skip to the next chunk
        #     process_and_save_answer(question='', chunk=chunk, 
        #                             steps=[], 
        #                             answer='', 
        #                             csv_filename=CSV_FILENAME, 
        #                             csv_headers=CSV_HEADERS,)
        #     continue

        all_answers_failed = True  # Flag to determine if all answers fail
        for question in questions.questions:
            for attempt in range(3):  # Retry up to 3 times for each question
                try:
                    logger.info(f"Generating answer for the question: {question.text} (attempt {attempt + 1}/3)")
                    A_response = generate_content(A_gen_template_prompt(chunk, question.text, a_schema), 1200)
                    logger.debug(f"A_response: {A_response}")
                    answer = ChainOfThought.model_validate_json(A_response)
                    logger.debug("Answer generated and validated successfully.")
                    all_answers_failed = False  # At least one answer succeeded
                    break  # Exit retry loop if successful
                except Exception as e:
                    logger.error(f"Error generating or validating answer (attempt {attempt + 1}/3): {e}", exc_info=True)
                    if attempt == 2:
                        logger.error(f"Maximum retries reached for question: {question.text}. Skipping this question.")

            if all_answers_failed:  # If all attempts fail for the current chunk, skip it
                logger.error("All answers failed. Skipping this chunk.")
                process_and_save_answer(question='', chunk=chunk, 
                                    steps=[], 
                                    answer='', 
                                    csv_filename=CSV_FILENAME, 
                                    csv_headers=CSV_HEADERS,)
                break

            process_and_save_answer(question=question.text, 
                                    chunk=chunk, 
                                    steps=[answer.steps[i].explanation for i in range(len(answer.steps))], 
                                    answer=answer.final_answer, 
                                    csv_filename=CSV_FILENAME, 
                                    csv_headers=CSV_HEADERS,)

        if all_answers_failed:
            continue  # Skip the chunk if no answers were generated successfully

    logger.info("Processing complete. Results are saved in the CSV file.")

if __name__ == '__main__':
    raw_data = pd.read_csv('craft.csv')
    docs = raw_data.context.to_list()
    indices = [2436, 2779, 4772, 4842, 5059, 5282]
    selected_docs = [docs[i] for i in indices]
    num_questions = 3 
    qa_data = run(selected_docs,num_questions)
    # print(raw_data.shape)
    # raw_data.head()
# Out:
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# complete chunks::   0%|                                                                                                                                         | 0/6 [00:00<?, ?it/s]2024-12-10 11:46:42,300 - INFO - Generating questions for the current chunk...
# 2024-12-10 11:46:45,978 - ERROR - Error generating or validating questions (attempt 1/3): 1 validation error for QuestionSet
# questions
#   Field required [type=missing, input_value={'$schema': 'http://json-..., 'title': 'Question'}}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# Traceback (most recent call last):
#   File "/tmp/ipykernel_3557271/3339747503.py", line 184, in run
#     questions = QuestionSet.model_validate_json(Q_response)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/main.py", line 597, in model_validate_json
#     return cls.__pydantic_validator__.validate_json(json_data, strict=strict, context=context)
# pydantic_core._pydantic_core.ValidationError: 1 validation error for QuestionSet
# questions
#   Field required [type=missing, input_value={'$schema': 'http://json-..., 'title': 'Question'}}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 2024-12-10 11:46:45,980 - INFO - Generating questions for the current chunk...
# 2024-12-10 11:46:50,469 - ERROR - Error generating or validating questions (attempt 2/3): 1 validation error for QuestionSet
# questions
#   Field required [type=missing, input_value={'$schema': 'http://json-... 'required': ['text']}}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# Traceback (most recent call last):
#   File "/tmp/ipykernel_3557271/3339747503.py", line 184, in run
#     questions = QuestionSet.model_validate_json(Q_response)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/main.py", line 597, in model_validate_json
#     return cls.__pydantic_validator__.validate_json(json_data, strict=strict, context=context)
# pydantic_core._pydantic_core.ValidationError: 1 validation error for QuestionSet
# questions
#   Field required [type=missing, input_value={'$schema': 'http://json-... 'required': ['text']}}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 2024-12-10 11:46:50,471 - INFO - Generating questions for the current chunk...
# 2024-12-10 11:46:54,773 - INFO - Generating answer for the question: What is the name of the fatty layer of the superficial fascia? (attempt 1/3)
# 2024-12-10 11:46:58,989 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-10 11:46:58,992 - INFO - Generating answer for the question: What is the name of the aponeurosis that is a continuation of the membranous layer of superficial fascia? (attempt 1/3)
# 2024-12-10 11:47:06,119 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-10 11:47:06,122 - INFO - Generating answer for the question: What is the name of the muscle that the aponeurosis of external oblique is attached to? (attempt 1/3)
# 2024-12-10 11:47:15,478 - INFO - Question and answer successfully appended to the CSV file.
# complete chunks::  17%|█████████████████████▌                                                                                                           | 1/6 [00:33<02:45, 33.18s/it]2024-12-10 11:47:15,482 - INFO - Generating questions for the current chunk...
# 2024-12-10 11:47:16,935 - INFO - Generating answer for the question: What is the purpose of a nephrostomy tube in the clinic? (attempt 1/3)
# 2024-12-10 11:47:26,250 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-10 11:47:26,252 - INFO - Generating answer for the question: How is the kidney accessed during a nephrostomy procedure? (attempt 1/3)
# 2024-12-10 11:47:31,255 - ERROR - Error generating or validating answer (attempt 1/3): 2 validation errors for ChainOfThought
# steps
#   Field required [type=missing, input_value={'$schema': 'http://json-...ep', 'type': 'object'}}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# final_answer
#   Field required [type=missing, input_value={'$schema': 'http://json-...ep', 'type': 'object'}}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# Traceback (most recent call last):
#   File "/tmp/ipykernel_3557271/3339747503.py", line 208, in run
#     answer = ChainOfThought.model_validate_json(A_response)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/main.py", line 597, in model_validate_json
#     return cls.__pydantic_validator__.validate_json(json_data, strict=strict, context=context)
# pydantic_core._pydantic_core.ValidationError: 2 validation errors for ChainOfThought
# steps
#   Field required [type=missing, input_value={'$schema': 'http://json-...ep', 'type': 'object'}}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# final_answer
#   Field required [type=missing, input_value={'$schema': 'http://json-...ep', 'type': 'object'}}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 2024-12-10 11:47:31,257 - INFO - Generating answer for the question: How is the kidney accessed during a nephrostomy procedure? (attempt 2/3)
# 2024-12-10 11:47:36,227 - ERROR - Error generating or validating answer (attempt 2/3): 2 validation errors for ChainOfThought
# steps
#   Field required [type=missing, input_value={'$schema': 'http://json-...ep', 'type': 'object'}}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# final_answer
#   Field required [type=missing, input_value={'$schema': 'http://json-...ep', 'type': 'object'}}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# Traceback (most recent call last):
#   File "/tmp/ipykernel_3557271/3339747503.py", line 208, in run
#     answer = ChainOfThought.model_validate_json(A_response)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/main.py", line 597, in model_validate_json
#     return cls.__pydantic_validator__.validate_json(json_data, strict=strict, context=context)
# pydantic_core._pydantic_core.ValidationError: 2 validation errors for ChainOfThought
# steps
#   Field required [type=missing, input_value={'$schema': 'http://json-...ep', 'type': 'object'}}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# final_answer
#   Field required [type=missing, input_value={'$schema': 'http://json-...ep', 'type': 'object'}}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 2024-12-10 11:47:36,228 - INFO - Generating answer for the question: How is the kidney accessed during a nephrostomy procedure? (attempt 3/3)
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# 2024-12-10 11:47:41,316 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-10 11:47:41,318 - INFO - Generating answer for the question: Why is access to the kidney relatively straightforward during a nephrostomy procedure? (attempt 1/3)
# 2024-12-10 11:47:43,974 - INFO - Question and answer successfully appended to the CSV file.
# complete chunks::  33%|███████████████████████████████████████████                                                                                      | 2/6 [01:01<02:01, 30.42s/it]2024-12-10 11:47:43,977 - INFO - Generating questions for the current chunk...
# 2024-12-10 11:47:47,068 - ERROR - Error generating or validating questions (attempt 1/3): 1 validation error for QuestionSet
# questions
#   Field required [type=missing, input_value={'$schema': 'http://json-... 'required': ['text']}}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# Traceback (most recent call last):
#   File "/tmp/ipykernel_3557271/3339747503.py", line 184, in run
#     questions = QuestionSet.model_validate_json(Q_response)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/main.py", line 597, in model_validate_json
#     return cls.__pydantic_validator__.validate_json(json_data, strict=strict, context=context)
# pydantic_core._pydantic_core.ValidationError: 1 validation error for QuestionSet
# questions
#   Field required [type=missing, input_value={'$schema': 'http://json-... 'required': ['text']}}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 2024-12-10 11:47:47,070 - INFO - Generating questions for the current chunk...
# 2024-12-10 11:47:52,590 - INFO - Generating answer for the question: What muscle is located in the gluteal region? (attempt 1/3)
# 2024-12-10 11:47:56,829 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-10 11:47:56,831 - INFO - Generating answer for the question: What is the name of the tendon that connects the quadriceps femoris muscle to the tibia? (attempt 1/3)
# 2024-12-10 11:48:01,164 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-10 11:48:01,165 - INFO - Generating answer for the question: Which nerve runs through the popliteal fossa? (attempt 1/3)
# 2024-12-10 11:48:12,603 - INFO - Question and answer successfully appended to the CSV file.
# complete chunks::  50%|████████████████████████████████████████████████████████████████▌                                                                | 3/6 [01:30<01:28, 29.60s/it]2024-12-10 11:48:12,606 - INFO - Generating questions for the current chunk...
# 2024-12-10 11:48:19,028 - INFO - Generating answer for the question: What is the primary cause of peripheral vascular disease? (attempt 1/3)
# 2024-12-10 11:48:22,182 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-10 11:48:22,183 - INFO - Generating answer for the question: What is the typical location of the narrowing in the lower aorta and its branches? (attempt 1/3)
# 2024-12-10 11:48:28,535 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-10 11:48:28,536 - INFO - Generating answer for the question: What is the name of the condition where vessels have undergone atheromatous change and there is significant luminal narrowing? (attempt 1/3)
# 2024-12-10 11:48:35,312 - INFO - Question and answer successfully appended to the CSV file.
# complete chunks::  67%|██████████████████████████████████████████████████████████████████████████████████████                                           | 4/6 [01:53<00:53, 26.88s/it]2024-12-10 11:48:35,314 - INFO - Generating questions for the current chunk...
# 2024-12-10 11:48:39,466 - INFO - Generating answer for the question: What are the four rotator cuff muscles that support the glenohumeral joint? (attempt 1/3)
# 2024-12-10 11:48:44,593 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-10 11:48:44,595 - INFO - Generating answer for the question: What is the main function of the muscles that connect the scapula and clavicle to the trunk? (attempt 1/3)
# 2024-12-10 11:48:52,165 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-10 11:48:52,167 - INFO - Generating answer for the question: What separates the muscles in the arm and forearm into two compartments? (attempt 1/3)
# 2024-12-10 11:48:57,413 - INFO - Question and answer successfully appended to the CSV file.
# complete chunks::  83%|███████████████████████████████████████████████████████████████████████████████████████████████████████████▌                     | 5/6 [02:15<00:25, 25.16s/it]2024-12-10 11:48:57,415 - INFO - Generating questions for the current chunk...
# 2024-12-10 11:48:59,078 - INFO - Generating answer for the question: What is the primary function of the cephalic vein in the upper limb? (attempt 1/3)
# 2024-12-10 11:49:02,254 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-10 11:49:02,255 - INFO - Generating answer for the question: Where does the cephalic vein pass into in the area of the shoulder? (attempt 1/3)
# 2024-12-10 11:49:09,270 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-10 11:49:09,272 - INFO - Generating answer for the question: What type of patients require replacement of blood or fluid, necessitating access to a peripheral vein? (attempt 1/3)
# 2024-12-10 11:49:13,238 - INFO - Question and answer successfully appended to the CSV file.
# complete chunks:: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 6/6 [02:30<00:00, 25.16s/it]
# 2024-12-10 11:49:13,243 - INFO - Processing complete. Results are saved in the CSV file.

# %%
import pandas as pd

# Create a sample DataFrame
df = pd.read_csv('craft_final.csv')
df.shape
# Out:
# (9054, 4)

# %%
duplicate = df[df.question.duplicated()]
 
print("Duplicate Rows :")
 
# Print the resultant Dataframe
duplicate
# Out:
# Duplicate Rows :
#                                                question  \
# 135   What type of joint allows movement around one ...
# 222   What is the primary function of sensory nerves...
# 228   Where do the cell bodies of visceral motor neu...
# 420   What forms the anterior wall of the vertebral ...
# 448   What is the function of the spinous process of...
# ...                                                 ...
# 8598  What percentage of strokes result from cerebra...
# 8787      What is the origin of the vertebral arteries?
# 8907  What is the function of the vermis in the cere...
# 8928  What arteries contribute to the formation of t...
# 9006  What is the primary function of the hypothalamus?
#
#                                                 context  \
# 135   The chunk is a description of different types ...
# 222   The provided chunk is a description of the vis...
# 228   The chunk is a section discussing the anatomy ...
# 420   The chunk can be situated within the document ...
# 448   The provided chunk is a description of the ver...
# ...                                                 ...
# 8598  The chunk is a medical case study discussing a...
# 8787  The chunk can be situated within the "Cerebral...
# 8907  The chunk can be situated within the document ...
# 8928  The provided chunk can be situated within the ...
# 9006  The chunk can be situated within the document ...
#
#                                                   steps  \
# 135   ['Read the description of the different types ...
# 222   ['First, we need to identify the question we a...
# 228   ['Identify the specific topic of the chunk, wh...
# 420   ['The question asks what forms the anterior wa...
# 448   ['Identify the components of the vertebral arc...
# ...                                                 ...
# 8598  ['##begin_quote## Eighty-five percent of all s...
# 8787  ['The context mentions that the vertebral arte...
# 8907  ['The question is asking about the function of...
# 8928  ['The question asks about the arteries that co...
# 9006  ['##begin_quote##The hypothalamus is a neuroen...
#
#                                               final_ans
# 135                                       Hinge joints.
# 222   detect changes related to chemoreception, mech...
# 228                                          A ganglion
# 420   The vertebral bodies of the vertebrae, interve...
# 448   The spinous process is a site for muscle and l...
# ...                                                 ...
# 8598                                                85%
# 8787                            The subclavian arteries
# 8907  The vermis controls movements along the axis o...
# 8928                            The vertebral arteries.
# 9006     Regulates physiological processes for survival
#
# [138 rows x 4 columns]

# %%
pd.read_csv('contextual_output.csv').shape
# Out:
# (3017, 3)

# %%
3017*3
# Out:
# 9051

# %% [markdown]
# ## load chunks from medrag

# %%
from datasets import load_dataset

ds = load_dataset("MedRAG/textbooks")
# Out:
# 2024-12-02 17:55:18,254 - INFO - PyTorch version 2.3.1 available.
# 2024-12-02 17:55:18,256 - INFO - TensorFlow version 2.17.0 available.
# Resolving data files:   0%|          | 0/18 [00:00<?, ?it/s]

# %%
df = ds['train'].to_pandas()  # Assuming you want the 'train' split
df.head()  # Display the first few rows
# Out:
#                id         title  \
# 0  Anatomy_Gray_0  Anatomy_Gray
# 1  Anatomy_Gray_1  Anatomy_Gray
# 2  Anatomy_Gray_2  Anatomy_Gray
# 3  Anatomy_Gray_3  Anatomy_Gray
# 4  Anatomy_Gray_4  Anatomy_Gray
#
#                                              content  \
# 0  What is anatomy? Anatomy includes those struct...
# 1  Observation and visualization are the primary ...
# 2  How can gross anatomy be studied? The term ana...
# 3  This includes the vasculature, the nerves, the...
# 4  Each of these approaches has benefits and defi...
#
#                                             contents
# 0  Anatomy_Gray. What is anatomy? Anatomy include...
# 1  Anatomy_Gray. Observation and visualization ar...
# 2  Anatomy_Gray. How can gross anatomy be studied...
# 3  Anatomy_Gray. This includes the vasculature, t...
# 4  Anatomy_Gray. Each of these approaches has ben...

# %%
anatomy_chunks = df[df['title']=='Anatomy_Gray']['content'].sort_index().to_list()

# %%
len(anatomy_chunks)
# Out:
# 3017

# %%
# chunks = ["Anatomy includes those structures that can be seen grossly (without the aid of magnification) and microscopically (with the aid of magnification). Typically, when used by itself, the term anatomy tends to mean gross or macroscopic anatomy—that is, the study of structures that can be seen without using a microscopic. Microscopic anatomy, also called histology, is the study of cells and tissues using a microscope."]
num_questions = 3 
qa_data = run(anatomy_chunks[:100],num_questions)
# Out:
# complete chunks::   0%|                                 | 0/100 [00:00<?, ?it/s]2024-12-02 17:57:43,242 - INFO - Generating questions for the current chunk...
# 2024-12-02 17:57:50,028 - INFO - Generating answer for the question: What is typically meant by the term anatomy when used by itself? (attempt 1/3)
# 2024-12-02 17:57:54,941 - ERROR - Error generating or validating answer (attempt 1/3): 2 validation errors for ChainOfThought
# steps
#   Field required [type=missing, input_value={'$schema': 'http://json-...ep', 'type': 'object'}}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# final_answer
#   Field required [type=missing, input_value={'$schema': 'http://json-...ep', 'type': 'object'}}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# Traceback (most recent call last):
#   File "/tmp/ipykernel_3371415/1813847204.py", line 158, in run
#     answer = ChainOfThought.model_validate_json(A_response)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/main.py", line 597, in model_validate_json
#     return cls.__pydantic_validator__.validate_json(json_data, strict=strict, context=context)
# pydantic_core._pydantic_core.ValidationError: 2 validation errors for ChainOfThought
# steps
#   Field required [type=missing, input_value={'$schema': 'http://json-...ep', 'type': 'object'}}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# final_answer
#   Field required [type=missing, input_value={'$schema': 'http://json-...ep', 'type': 'object'}}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 2024-12-02 17:57:54,945 - INFO - Generating answer for the question: What is typically meant by the term anatomy when used by itself? (attempt 2/3)
# 2024-12-02 17:57:58,451 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-02 17:57:58,452 - INFO - Generating answer for the question: What is microscopic anatomy also called? (attempt 1/3)
# 2024-12-02 17:58:07,395 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-02 17:58:07,398 - INFO - Generating answer for the question: What is the basis for the practice of medicine? (attempt 1/3)
# 2024-12-02 17:58:09,886 - INFO - Question and answer successfully appended to the CSV file.
# complete chunks::   1%|▎                        | 1/100 [00:26<43:57, 26.65s/it]2024-12-02 17:58:09,888 - INFO - Generating questions for the current chunk...
# 2024-12-02 17:58:16,368 - INFO - Generating answer for the question: What are the two primary techniques a student should use to learn anatomy? (attempt 1/3)
# 2024-12-02 17:58:25,076 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-02 17:58:25,077 - INFO - Generating answer for the question: What is the difference between memorizing the names of the branches of the external carotid artery and being able to visualize its course? (attempt 1/3)
# 2024-12-02 17:58:32,916 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-02 17:58:32,919 - INFO - Generating answer for the question: How does understanding the context of anatomy terminology differ from just memorizing names of structures? (attempt 1/3)
# 2024-12-02 17:58:41,062 - INFO - Question and answer successfully appended to the CSV file.
# complete chunks::   2%|▌                        | 2/100 [00:57<47:52, 29.31s/it]2024-12-02 17:58:41,064 - INFO - Generating questions for the current chunk...
# 2024-12-02 17:58:42,687 - INFO - Generating answer for the question: What is the origin of the term anatomy? (attempt 1/3)
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# 2024-12-02 17:58:47,205 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-02 17:58:47,206 - INFO - Generating answer for the question: What is the primary method of studying anatomy? (attempt 1/3)
# 2024-12-02 17:58:56,356 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-02 17:58:56,358 - INFO - Generating answer for the question: What is an alternative to dissection of cadavers for studying anatomy? (attempt 1/3)
# 2024-12-02 17:59:00,200 - INFO - Question and answer successfully appended to the CSV file.
# complete chunks::   3%|▊                        | 3/100 [01:16<39:52, 24.67s/it]2024-12-02 17:59:00,202 - INFO - Generating questions for the current chunk...
# 2024-12-02 17:59:01,570 - INFO - Generating answer for the question: What are the regions of the body studied after the thorax? (attempt 1/3)
# 2024-12-02 17:59:07,759 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-02 17:59:07,760 - INFO - Generating answer for the question: What are the systems studied in a systemic approach? (attempt 1/3)
# 2024-12-02 17:59:12,679 - ERROR - Error generating or validating answer (attempt 1/3): 2 validation errors for ChainOfThought
# steps
#   Field required [type=missing, input_value={'$schema': 'http://json-...ep', 'type': 'object'}}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# final_answer
#   Field required [type=missing, input_value={'$schema': 'http://json-...ep', 'type': 'object'}}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# Traceback (most recent call last):
#   File "/tmp/ipykernel_3371415/1813847204.py", line 158, in run
#     answer = ChainOfThought.model_validate_json(A_response)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/main.py", line 597, in model_validate_json
#     return cls.__pydantic_validator__.validate_json(json_data, strict=strict, context=context)
# pydantic_core._pydantic_core.ValidationError: 2 validation errors for ChainOfThought
# steps
#   Field required [type=missing, input_value={'$schema': 'http://json-...ep', 'type': 'object'}}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# final_answer
#   Field required [type=missing, input_value={'$schema': 'http://json-...ep', 'type': 'object'}}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 2024-12-02 17:59:12,680 - INFO - Generating answer for the question: What are the systems studied in a systemic approach? (attempt 2/3)
# 2024-12-02 17:59:18,538 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-02 17:59:18,540 - INFO - Generating answer for the question: Which system looks at the heart and all of the blood vessels in the body? (attempt 1/3)
# 2024-12-02 17:59:32,216 - INFO - Question and answer successfully appended to the CSV file.
# complete chunks::   4%|█                        | 4/100 [01:48<44:06, 27.57s/it]2024-12-02 17:59:32,218 - INFO - Generating questions for the current chunk...
# 2024-12-02 17:59:33,587 - INFO - Generating answer for the question: What are the benefits of the regional approach in an anatomy course? (attempt 1/3)
# 2024-12-02 17:59:37,579 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-02 17:59:37,580 - INFO - Generating answer for the question: What is a limitation of the regional approach in an anatomy course? (attempt 1/3)
# 2024-12-02 17:59:42,542 - ERROR - Error generating or validating answer (attempt 1/3): 2 validation errors for ChainOfThought
# steps
#   Field required [type=missing, input_value={'$schema': 'http://json-...ep', 'type': 'object'}}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# final_answer
#   Field required [type=missing, input_value={'$schema': 'http://json-...ep', 'type': 'object'}}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# Traceback (most recent call last):
#   File "/tmp/ipykernel_3371415/1813847204.py", line 158, in run
#     answer = ChainOfThought.model_validate_json(A_response)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/main.py", line 597, in model_validate_json
#     return cls.__pydantic_validator__.validate_json(json_data, strict=strict, context=context)
# pydantic_core._pydantic_core.ValidationError: 2 validation errors for ChainOfThought
# steps
#   Field required [type=missing, input_value={'$schema': 'http://json-...ep', 'type': 'object'}}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# final_answer
#   Field required [type=missing, input_value={'$schema': 'http://json-...ep', 'type': 'object'}}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 2024-12-02 17:59:42,544 - INFO - Generating answer for the question: What is a limitation of the regional approach in an anatomy course? (attempt 2/3)
# 2024-12-02 17:59:48,114 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-02 17:59:48,116 - INFO - Generating answer for the question: What is a difficulty with the systemic approach in an anatomy course? (attempt 1/3)
# 2024-12-02 17:59:53,928 - INFO - Question and answer successfully appended to the CSV file.
# complete chunks::   5%|█▎                       | 5/100 [02:10<40:18, 25.46s/it]2024-12-02 17:59:53,931 - INFO - Generating questions for the current chunk...
# 2024-12-02 17:59:58,124 - INFO - Generating answer for the question: What is the standard reference position of the body used to describe the location of structures? (attempt 1/3)
# 2024-12-02 18:00:04,379 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-02 18:00:04,380 - INFO - Generating answer for the question: How are the hands positioned in the anatomical position? (attempt 1/3)
# 2024-12-02 18:00:06,858 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-02 18:00:06,859 - INFO - Generating answer for the question: What is the orientation of coronal planes in the anatomical position? (attempt 1/3)
# 2024-12-02 18:00:11,861 - INFO - Question and answer successfully appended to the CSV file.
# complete chunks::   6%|█▌                       | 6/100 [02:28<35:52, 22.90s/it]2024-12-02 18:00:11,863 - INFO - Generating questions for the current chunk...
# 2024-12-02 18:00:13,342 - INFO - Generating answer for the question: What is the orientation of coronal planes in the anatomical position? (attempt 1/3)
# 2024-12-02 18:00:18,692 - ERROR - Error generating or validating answer (attempt 1/3): 2 validation errors for ChainOfThought
# steps
#   Field required [type=missing, input_value={'$schema': 'http://json-...ep', 'type': 'object'}}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# final_answer
#   Field required [type=missing, input_value={'$schema': 'http://json-...ep', 'type': 'object'}}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# Traceback (most recent call last):
#   File "/tmp/ipykernel_3371415/1813847204.py", line 158, in run
#     answer = ChainOfThought.model_validate_json(A_response)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/main.py", line 597, in model_validate_json
#     return cls.__pydantic_validator__.validate_json(json_data, strict=strict, context=context)
# pydantic_core._pydantic_core.ValidationError: 2 validation errors for ChainOfThought
# steps
#   Field required [type=missing, input_value={'$schema': 'http://json-...ep', 'type': 'object'}}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# final_answer
#   Field required [type=missing, input_value={'$schema': 'http://json-...ep', 'type': 'object'}}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 2024-12-02 18:00:18,694 - INFO - Generating answer for the question: What is the orientation of coronal planes in the anatomical position? (attempt 2/3)
# 2024-12-02 18:00:22,411 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-02 18:00:22,413 - INFO - Generating answer for the question: What is the function of the median sagittal plane? (attempt 1/3)
# 2024-12-02 18:00:30,797 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-02 18:00:30,799 - INFO - Generating answer for the question: What is the name of the planes that divide the body into superior and inferior parts? (attempt 1/3)
# 2024-12-02 18:00:33,943 - INFO - Question and answer successfully appended to the CSV file.
# complete chunks::   7%|█▊                       | 7/100 [02:50<35:04, 22.63s/it]2024-12-02 18:00:33,945 - INFO - Generating questions for the current chunk...
# 2024-12-02 18:00:37,992 - ERROR - Error generating or validating questions (attempt 1/3): 1 validation error for QuestionSet
# questions
#   Field required [type=missing, input_value={'$schema': 'http://json-...on', 'type': 'object'}}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# Traceback (most recent call last):
#   File "/tmp/ipykernel_3371415/1813847204.py", line 139, in run
#     questions = QuestionSet.model_validate_json(Q_response)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/main.py", line 597, in model_validate_json
#     return cls.__pydantic_validator__.validate_json(json_data, strict=strict, context=context)
# pydantic_core._pydantic_core.ValidationError: 1 validation error for QuestionSet
# questions
#   Field required [type=missing, input_value={'$schema': 'http://json-...on', 'type': 'object'}}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 2024-12-02 18:00:37,993 - INFO - Generating questions for the current chunk...
# 2024-12-02 18:00:39,604 - INFO - Generating answer for the question: What is the position of the nose relative to the body? (attempt 1/3)
# 2024-12-02 18:00:46,311 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-02 18:00:46,312 - INFO - Generating answer for the question: Which structure is posterior to the sternum? (attempt 1/3)
# 2024-12-02 18:00:50,590 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-02 18:00:50,591 - INFO - Generating answer for the question: Is the thumb medial or lateral to the little finger? (attempt 1/3)
# 2024-12-02 18:00:53,730 - INFO - Question and answer successfully appended to the CSV file.
# complete chunks::   8%|██                       | 8/100 [03:10<33:18, 21.73s/it]2024-12-02 18:00:53,732 - INFO - Generating questions for the current chunk...
# 2024-12-02 18:00:56,080 - INFO - Generating answer for the question: What is the term used to describe a structure that is closer to the origin of a system? (attempt 1/3)
# 2024-12-02 18:01:00,030 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-02 18:01:00,032 - INFO - Generating answer for the question: Which joint is proximal to the elbow joint? (attempt 1/3)
# 2024-12-02 18:01:03,373 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-02 18:01:03,374 - INFO - Generating answer for the question: What is the term used to describe a structure that is farther away from the origin of a system? (attempt 1/3)
# 2024-12-02 18:01:07,044 - INFO - Question and answer successfully appended to the CSV file.
# complete chunks::   9%|██▎                      | 9/100 [03:23<28:57, 19.10s/it]2024-12-02 18:01:07,046 - INFO - Generating questions for the current chunk...
# 2024-12-02 18:01:12,551 - INFO - Generating answer for the question: What term is used to describe the position of a structure with reference to the nose? (attempt 1/3)
# 2024-12-02 18:01:15,249 - ERROR - Error generating or validating answer (attempt 1/3): 1 validation error for ChainOfThought
# steps.0.explanation
#   Field required [type=missing, input_value={'$ref': '#/$defs/Step'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# Traceback (most recent call last):
#   File "/tmp/ipykernel_3371415/1813847204.py", line 158, in run
#     answer = ChainOfThought.model_validate_json(A_response)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/main.py", line 597, in model_validate_json
#     return cls.__pydantic_validator__.validate_json(json_data, strict=strict, context=context)
# pydantic_core._pydantic_core.ValidationError: 1 validation error for ChainOfThought
# steps.0.explanation
#   Field required [type=missing, input_value={'$ref': '#/$defs/Step'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 2024-12-02 18:01:15,250 - INFO - Generating answer for the question: What term is used to describe the position of a structure with reference to the nose? (attempt 2/3)
# 2024-12-02 18:01:19,912 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-02 18:01:19,913 - INFO - Generating answer for the question: Which organ is superficial to the abdominal wall? (attempt 1/3)
# 2024-12-02 18:01:25,336 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-02 18:01:25,337 - INFO - Generating answer for the question: What term is used to describe the relative positions of two structures with respect to the surface of the body? (attempt 1/3)
# 2024-12-02 18:01:30,347 - INFO - Question and answer successfully appended to the CSV file.
# complete chunks::  10%|██▍                     | 10/100 [03:47<30:35, 20.39s/it]2024-12-02 18:01:30,349 - INFO - Generating questions for the current chunk...
# 2024-12-02 18:01:35,926 - INFO - Generating answer for the question: What are the structures that are enclosed by the outer layer of deep fascia? (attempt 1/3)
# 2024-12-02 18:01:39,744 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-02 18:01:39,745 - INFO - Generating answer for the question: What is the term for wounds that penetrate through the outer layer of deep fascia? (attempt 1/3)
# 2024-12-02 18:01:45,269 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-02 18:01:45,270 - INFO - Generating answer for the question: Who produced the first radiographic exposure of his wife's hand in 1895? (attempt 1/3)
# 2024-12-02 18:01:52,377 - INFO - Question and answer successfully appended to the CSV file.
# complete chunks::  11%|██▋                     | 11/100 [04:09<30:59, 20.90s/it]2024-12-02 18:01:52,379 - INFO - Generating questions for the current chunk...
# 2024-12-02 18:01:56,426 - ERROR - Error generating or validating questions (attempt 1/3): 1 validation error for QuestionSet
# questions
#   Field required [type=missing, input_value={'$schema': 'http://json-...nSet', 'type': 'object'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# Traceback (most recent call last):
#   File "/tmp/ipykernel_3371415/1813847204.py", line 139, in run
#     questions = QuestionSet.model_validate_json(Q_response)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/main.py", line 597, in model_validate_json
#     return cls.__pydantic_validator__.validate_json(json_data, strict=strict, context=context)
# pydantic_core._pydantic_core.ValidationError: 1 validation error for QuestionSet
# questions
#   Field required [type=missing, input_value={'$schema': 'http://json-...nSet', 'type': 'object'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 2024-12-02 18:01:56,428 - INFO - Generating questions for the current chunk...
# 2024-12-02 18:02:00,496 - ERROR - Error generating or validating questions (attempt 2/3): 1 validation error for QuestionSet
# questions
#   Field required [type=missing, input_value={'$schema': 'http://json-... 'required': ['text']}}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# Traceback (most recent call last):
#   File "/tmp/ipykernel_3371415/1813847204.py", line 139, in run
#     questions = QuestionSet.model_validate_json(Q_response)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/main.py", line 597, in model_validate_json
#     return cls.__pydantic_validator__.validate_json(json_data, strict=strict, context=context)
# pydantic_core._pydantic_core.ValidationError: 1 validation error for QuestionSet
# questions
#   Field required [type=missing, input_value={'$schema': 'http://json-... 'required': ['text']}}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 2024-12-02 18:02:00,497 - INFO - Generating questions for the current chunk...
# 2024-12-02 18:02:02,767 - INFO - Generating answer for the question: What type of radiation are X-rays? (attempt 1/3)
# 2024-12-02 18:02:09,658 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-02 18:02:09,661 - INFO - Generating answer for the question: What is the purpose of lead-lined shutters in the X-ray machine? (attempt 1/3)
# 2024-12-02 18:02:14,531 - ERROR - Error generating or validating answer (attempt 1/3): 2 validation errors for ChainOfThought
# steps
#   Field required [type=missing, input_value={'$schema': 'http://json-...ep', 'type': 'object'}}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# final_answer
#   Field required [type=missing, input_value={'$schema': 'http://json-...ep', 'type': 'object'}}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# Traceback (most recent call last):
#   File "/tmp/ipykernel_3371415/1813847204.py", line 158, in run
#     answer = ChainOfThought.model_validate_json(A_response)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/main.py", line 597, in model_validate_json
#     return cls.__pydantic_validator__.validate_json(json_data, strict=strict, context=context)
# pydantic_core._pydantic_core.ValidationError: 2 validation errors for ChainOfThought
# steps
#   Field required [type=missing, input_value={'$schema': 'http://json-...ep', 'type': 'object'}}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# final_answer
#   Field required [type=missing, input_value={'$schema': 'http://json-...ep', 'type': 'object'}}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 2024-12-02 18:02:14,532 - INFO - Generating answer for the question: What is the purpose of lead-lined shutters in the X-ray machine? (attempt 2/3)
# 2024-12-02 18:02:18,794 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-02 18:02:18,795 - INFO - Generating answer for the question: Which tissue in the body attenuates X-rays the most? (attempt 1/3)
# 2024-12-02 18:02:25,877 - INFO - Question and answer successfully appended to the CSV file.
# complete chunks::  12%|██▉                     | 12/100 [04:42<36:16, 24.73s/it]2024-12-02 18:02:25,879 - INFO - Generating questions for the current chunk...
# 2024-12-02 18:02:28,394 - INFO - Generating answer for the question: What is the main purpose of the X-ray technique described in the text? (attempt 1/3)
# 2024-12-02 18:02:33,475 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-02 18:02:33,476 - INFO - Generating answer for the question: What is produced from the X-ray tube in the described technique? (attempt 1/3)
# 2024-12-02 18:02:36,713 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-02 18:02:36,714 - INFO - Generating answer for the question: What type of studies can be performed using the described technique? (attempt 1/3)
# 2024-12-02 18:02:42,459 - INFO - Question and answer successfully appended to the CSV file.
# complete chunks::  13%|███                     | 13/100 [04:59<32:16, 22.26s/it]2024-12-02 18:02:42,461 - INFO - Generating questions for the current chunk...
# 2024-12-02 18:02:47,966 - INFO - Generating answer for the question: What is the primary purpose of adding air to a barium sulfate suspension in a medical examination? (attempt 1/3)
# 2024-12-02 18:02:54,599 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-02 18:02:54,600 - INFO - Generating answer for the question: Is barium sulfate a toxic substance? (attempt 1/3)
# 2024-12-02 18:02:58,194 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-02 18:02:58,195 - INFO - Generating answer for the question: What is the name of the study that uses both air and barium sulfate for imaging? (attempt 1/3)
# 2024-12-02 18:03:01,956 - INFO - Question and answer successfully appended to the CSV file.
# complete chunks::  14%|███▎                    | 14/100 [05:18<30:42, 21.43s/it]2024-12-02 18:03:01,958 - INFO - Generating questions for the current chunk...
# 2024-12-02 18:03:04,796 - INFO - Generating answer for the question: What are some potential risks associated with intra-arterial or intravenous injections? (attempt 1/3)
# 2024-12-02 18:03:11,064 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-02 18:03:11,065 - INFO - Generating answer for the question: How do intra-arterial and intravenous contrast agents help in visualizing the urinary system? (attempt 1/3)
# 2024-12-02 18:03:18,292 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-02 18:03:18,293 - INFO - Generating answer for the question: What is the process called when contrast agents are used to visualize the kidneys, ureter, and bladder? (attempt 1/3)
# 2024-12-02 18:03:22,041 - INFO - Question and answer successfully appended to the CSV file.
# complete chunks::  15%|███▌                    | 15/100 [05:38<29:46, 21.02s/it]2024-12-02 18:03:22,045 - INFO - Generating questions for the current chunk...
# 2024-12-02 18:03:27,644 - INFO - Generating answer for the question: What is the main challenge in appreciating contrast agent in vessels during angiography? (attempt 1/3)
# 2024-12-02 18:03:33,684 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-02 18:03:33,685 - INFO - Generating answer for the question: How is the contrast agent made visible in the vessels during angiography? (attempt 1/3)
# 2024-12-02 18:03:45,590 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-02 18:03:45,591 - INFO - Generating answer for the question: What is the name of the technique used to make the contrast agent visible in the vessels during angiography? (attempt 1/3)
# 2024-12-02 18:03:53,755 - INFO - Question and answer successfully appended to the CSV file.
# complete chunks::  16%|███▊                    | 16/100 [06:10<33:56, 24.24s/it]2024-12-02 18:03:53,758 - INFO - Generating questions for the current chunk...
# 2024-12-02 18:03:59,118 - INFO - Generating answer for the question: What is the nature of the sound wave used in ultrasonography? (attempt 1/3)
# 2024-12-02 18:04:05,274 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-02 18:04:05,275 - INFO - Generating answer for the question: How are the sound waves received in ultrasonography? (attempt 1/3)
# 2024-12-02 18:04:10,140 - ERROR - Error generating or validating answer (attempt 1/3): 2 validation errors for ChainOfThought
# steps
#   Field required [type=missing, input_value={'$schema': 'http://json-...ep', 'type': 'object'}}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# final_answer
#   Field required [type=missing, input_value={'$schema': 'http://json-...ep', 'type': 'object'}}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# Traceback (most recent call last):
#   File "/tmp/ipykernel_3371415/1813847204.py", line 158, in run
#     answer = ChainOfThought.model_validate_json(A_response)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/main.py", line 597, in model_validate_json
#     return cls.__pydantic_validator__.validate_json(json_data, strict=strict, context=context)
# pydantic_core._pydantic_core.ValidationError: 2 validation errors for ChainOfThought
# steps
#   Field required [type=missing, input_value={'$schema': 'http://json-...ep', 'type': 'object'}}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# final_answer
#   Field required [type=missing, input_value={'$schema': 'http://json-...ep', 'type': 'object'}}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 2024-12-02 18:04:10,141 - INFO - Generating answer for the question: How are the sound waves received in ultrasonography? (attempt 2/3)
# 2024-12-02 18:04:13,244 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-02 18:04:13,245 - INFO - Generating answer for the question: What technology has led to a broader range of areas being scanned using ultrasound? (attempt 1/3)
# 2024-12-02 18:04:18,196 - INFO - Question and answer successfully appended to the CSV file.
# complete chunks::  17%|████                    | 17/100 [06:34<33:36, 24.30s/it]2024-12-02 18:04:18,198 - INFO - Generating questions for the current chunk...
# 2024-12-02 18:04:24,168 - INFO - Generating answer for the question: What are some common areas that ultrasound is used to assess? (attempt 1/3)
# 2024-12-02 18:04:29,143 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-02 18:04:29,144 - INFO - Generating answer for the question: In which women is transvaginal ultrasound most commonly used? (attempt 1/3)
# 2024-12-02 18:04:35,775 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-02 18:04:35,778 - INFO - Generating answer for the question: What is the imaging method of choice for assessing the prostate in men? (attempt 1/3)
# 2024-12-02 18:04:38,103 - INFO - Question and answer successfully appended to the CSV file.
# complete chunks::  18%|████▎                   | 18/100 [06:54<31:24, 22.98s/it]2024-12-02 18:04:38,105 - INFO - Generating questions for the current chunk...
# 2024-12-02 18:04:39,673 - INFO - Generating answer for the question: What is used to determine flow, direction, and velocity within a vessel using simple ultrasound techniques? (attempt 1/3)
# 2024-12-02 18:04:45,442 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-02 18:04:45,443 - INFO - Generating answer for the question: What is the primary method to obtain precise measurements of blood flow and blood velocity? (attempt 1/3)
# 2024-12-02 18:04:51,141 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-02 18:04:51,142 - INFO - Generating answer for the question: Who was awarded the Nobel Prize in Medicine in 1979? (attempt 1/3)
# 2024-12-02 18:04:55,989 - ERROR - Error generating or validating answer (attempt 1/3): 2 validation errors for ChainOfThought
# steps
#   Field required [type=missing, input_value={'$schema': 'http://json-...ep', 'type': 'object'}}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# final_answer
#   Field required [type=missing, input_value={'$schema': 'http://json-...ep', 'type': 'object'}}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# Traceback (most recent call last):
#   File "/tmp/ipykernel_3371415/1813847204.py", line 158, in run
#     answer = ChainOfThought.model_validate_json(A_response)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/main.py", line 597, in model_validate_json
#     return cls.__pydantic_validator__.validate_json(json_data, strict=strict, context=context)
# pydantic_core._pydantic_core.ValidationError: 2 validation errors for ChainOfThought
# steps
#   Field required [type=missing, input_value={'$schema': 'http://json-...ep', 'type': 'object'}}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# final_answer
#   Field required [type=missing, input_value={'$schema': 'http://json-...ep', 'type': 'object'}}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 2024-12-02 18:04:55,991 - INFO - Generating answer for the question: Who was awarded the Nobel Prize in Medicine in 1979? (attempt 2/3)
# 2024-12-02 18:05:00,856 - ERROR - Error generating or validating answer (attempt 2/3): 2 validation errors for ChainOfThought
# steps
#   Field required [type=missing, input_value={'$schema': 'http://json-...on'], 'title': 'Step'}}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# final_answer
#   Field required [type=missing, input_value={'$schema': 'http://json-...on'], 'title': 'Step'}}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# Traceback (most recent call last):
#   File "/tmp/ipykernel_3371415/1813847204.py", line 158, in run
#     answer = ChainOfThought.model_validate_json(A_response)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/main.py", line 597, in model_validate_json
#     return cls.__pydantic_validator__.validate_json(json_data, strict=strict, context=context)
# pydantic_core._pydantic_core.ValidationError: 2 validation errors for ChainOfThought
# steps
#   Field required [type=missing, input_value={'$schema': 'http://json-...on'], 'title': 'Step'}}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# final_answer
#   Field required [type=missing, input_value={'$schema': 'http://json-...on'], 'title': 'Step'}}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 2024-12-02 18:05:00,857 - INFO - Generating answer for the question: Who was awarded the Nobel Prize in Medicine in 1979? (attempt 3/3)
# 2024-12-02 18:05:06,653 - INFO - Question and answer successfully appended to the CSV file.
# complete chunks::  19%|████▌                   | 19/100 [07:23<33:16, 24.65s/it]2024-12-02 18:05:06,655 - INFO - Generating questions for the current chunk...
# 2024-12-02 18:05:09,206 - INFO - Generating answer for the question: What is the purpose of the X-ray tube in a CT scanner? (attempt 1/3)
# 2024-12-02 18:05:14,046 - ERROR - Error generating or validating answer (attempt 1/3): 2 validation errors for ChainOfThought
# steps
#   Field required [type=missing, input_value={'$schema': 'http://json-...ep', 'type': 'object'}}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# final_answer
#   Field required [type=missing, input_value={'$schema': 'http://json-...ep', 'type': 'object'}}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# Traceback (most recent call last):
#   File "/tmp/ipykernel_3371415/1813847204.py", line 158, in run
#     answer = ChainOfThought.model_validate_json(A_response)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/main.py", line 597, in model_validate_json
#     return cls.__pydantic_validator__.validate_json(json_data, strict=strict, context=context)
# pydantic_core._pydantic_core.ValidationError: 2 validation errors for ChainOfThought
# steps
#   Field required [type=missing, input_value={'$schema': 'http://json-...ep', 'type': 'object'}}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# final_answer
#   Field required [type=missing, input_value={'$schema': 'http://json-...ep', 'type': 'object'}}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 2024-12-02 18:05:14,049 - INFO - Generating answer for the question: What is the purpose of the X-ray tube in a CT scanner? (attempt 2/3)
# 2024-12-02 18:05:19,987 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-02 18:05:19,989 - INFO - Generating answer for the question: What is the final product of the mathematical transformation performed by the computer in a CT scanner? (attempt 1/3)
# 2024-12-02 18:05:22,958 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-02 18:05:22,959 - INFO - Generating answer for the question: In which plane are the images obtained by a CT scanner? (attempt 1/3)
# 2024-12-02 18:05:29,110 - INFO - Question and answer successfully appended to the CSV file.
# complete chunks::  20%|████▊                   | 20/100 [07:45<31:59, 23.99s/it]2024-12-02 18:05:29,112 - INFO - Generating questions for the current chunk...
# 2024-12-02 18:05:30,650 - INFO - Generating answer for the question: In what year was Nuclear magnetic resonance imaging first described? (attempt 1/3)
# 2024-12-02 18:05:37,480 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-02 18:05:37,481 - INFO - Generating answer for the question: What is the primary component of biological tissues that MRI depends on? (attempt 1/3)
# 2024-12-02 18:05:42,376 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-02 18:05:42,377 - INFO - Generating answer for the question: What happens to the bar magnets in the patient's hydrogen nuclei when a pulse of radio waves is passed through them? (attempt 1/3)
# 2024-12-02 18:05:46,034 - INFO - Question and answer successfully appended to the CSV file.
# complete chunks::  21%|█████                   | 21/100 [08:02<28:47, 21.87s/it]2024-12-02 18:05:46,037 - INFO - Generating questions for the current chunk...
# 2024-12-02 18:05:51,591 - INFO - Generating answer for the question: What type of images are obtained when the pulse sequence is altered to provide differences in image contrast? (attempt 1/3)
# 2024-12-02 18:05:57,393 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-02 18:05:57,394 - INFO - Generating answer for the question: What is the appearance of cerebrospinal fluid in T1-weighted images? (attempt 1/3)
# 2024-12-02 18:06:01,022 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-02 18:06:01,023 - INFO - Generating answer for the question: What type of imaging sequences can be used to assess flow within vessels? (attempt 1/3)
# 2024-12-02 18:06:05,279 - INFO - Question and answer successfully appended to the CSV file.
# complete chunks::  22%|█████▎                  | 22/100 [08:22<27:24, 21.08s/it]2024-12-02 18:06:05,281 - INFO - Generating questions for the current chunk...
# 2024-12-02 18:06:11,564 - INFO - Generating answer for the question: What is the main difference between gamma rays and X-rays? (attempt 1/3)
# 2024-12-02 18:06:17,474 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-02 18:06:17,476 - INFO - Generating answer for the question: How does diffusion-weighted imaging provide information on the degree of Brownian motion of water molecules in tissues? (attempt 1/3)
# 2024-12-02 18:06:24,945 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-02 18:06:24,947 - INFO - Generating answer for the question: What happens to the degree of diffusion in tumors and infarcted tissue compared to normal tissue? (attempt 1/3)
# 2024-12-02 18:06:29,014 - INFO - Question and answer successfully appended to the CSV file.
# complete chunks::  23%|█████▌                  | 23/100 [08:45<28:04, 21.88s/it]2024-12-02 18:06:29,016 - INFO - Generating questions for the current chunk...
# 2024-12-02 18:06:33,362 - ERROR - Error generating or validating questions (attempt 1/3): 1 validation error for QuestionSet
# questions
#   Field required [type=missing, input_value={'$schema': 'http://json-... 'required': ['text']}}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# Traceback (most recent call last):
#   File "/tmp/ipykernel_3371415/1813847204.py", line 139, in run
#     questions = QuestionSet.model_validate_json(Q_response)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/main.py", line 597, in model_validate_json
#     return cls.__pydantic_validator__.validate_json(json_data, strict=strict, context=context)
# pydantic_core._pydantic_core.ValidationError: 1 validation error for QuestionSet
# questions
#   Field required [type=missing, input_value={'$schema': 'http://json-... 'required': ['text']}}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 2024-12-02 18:06:33,363 - INFO - Generating questions for the current chunk...
# 2024-12-02 18:06:35,004 - ERROR - Error generating or validating questions (attempt 2/3): 1 validation error for QuestionSet
#   Invalid JSON: expected `,` or `]` at line 4 column 19 [type=json_invalid, input_value=' {\n        "questions":...ing?"\n        ]\n    }', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.8/v/json_invalid
# Traceback (most recent call last):
#   File "/tmp/ipykernel_3371415/1813847204.py", line 139, in run
#     questions = QuestionSet.model_validate_json(Q_response)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/main.py", line 597, in model_validate_json
#     return cls.__pydantic_validator__.validate_json(json_data, strict=strict, context=context)
# pydantic_core._pydantic_core.ValidationError: 1 validation error for QuestionSet
#   Invalid JSON: expected `,` or `]` at line 4 column 19 [type=json_invalid, input_value=' {\n        "questions":...ing?"\n        ]\n    }', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.8/v/json_invalid
# 2024-12-02 18:06:35,005 - INFO - Generating questions for the current chunk...
# 2024-12-02 18:06:36,746 - INFO - Generating answer for the question: What is the primary source of gamma rays in an X-ray? (attempt 1/3)
# 2024-12-02 18:06:39,965 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-02 18:06:39,966 - INFO - Generating answer for the question: What is the required half-life for a gamma ray emitter to be useful for visualization? (attempt 1/3)
# 2024-12-02 18:06:43,504 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-02 18:06:43,505 - INFO - Generating answer for the question: How long should the energy deposition in a patient's tissues be in order for the gamma ray emitter to be useful? (attempt 1/3)
# 2024-12-02 18:06:51,172 - ERROR - Error generating or validating answer (attempt 1/3): 1 validation error for ChainOfThought
#   Invalid JSON: EOF while parsing an object at line 19 column 38 [type=json_invalid, input_value=' {\n  "$defs": {\n    "S...": "as low as possible"', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.8/v/json_invalid
# Traceback (most recent call last):
#   File "/tmp/ipykernel_3371415/1813847204.py", line 158, in run
#     answer = ChainOfThought.model_validate_json(A_response)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/main.py", line 597, in model_validate_json
#     return cls.__pydantic_validator__.validate_json(json_data, strict=strict, context=context)
# pydantic_core._pydantic_core.ValidationError: 1 validation error for ChainOfThought
#   Invalid JSON: EOF while parsing an object at line 19 column 38 [type=json_invalid, input_value=' {\n  "$defs": {\n    "S...": "as low as possible"', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.8/v/json_invalid
# 2024-12-02 18:06:51,173 - INFO - Generating answer for the question: How long should the energy deposition in a patient's tissues be in order for the gamma ray emitter to be useful? (attempt 2/3)
# 2024-12-02 18:06:57,517 - INFO - Question and answer successfully appended to the CSV file.
# complete chunks::  24%|█████▊                  | 24/100 [09:14<30:13, 23.87s/it]2024-12-02 18:06:57,519 - INFO - Generating questions for the current chunk...
# 2024-12-02 18:07:01,944 - INFO - Generating answer for the question: What is the most commonly used radionuclide in medical imaging? (attempt 1/3)
# 2024-12-02 18:07:12,333 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-02 18:07:12,335 - INFO - Generating answer for the question: What is technetium-99m combined with to produce a radiopharmaceutical for bone assessment? (attempt 1/3)
# 2024-12-02 18:07:14,664 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-02 18:07:14,665 - INFO - Generating answer for the question: How are images obtained after injection of a technetium-99m radiopharmaceutical? (attempt 1/3)
# 2024-12-02 18:07:19,282 - INFO - Question and answer successfully appended to the CSV file.
# complete chunks::  25%|██████                  | 25/100 [09:36<29:02, 23.24s/it]2024-12-02 18:07:19,284 - INFO - Generating questions for the current chunk...
# 2024-12-02 18:07:21,139 - INFO - Generating answer for the question: What is the purpose of a gamma camera in obtaining images after the injection of a radiopharmaceutical? (attempt 1/3)
# 2024-12-02 18:07:25,993 - ERROR - Error generating or validating answer (attempt 1/3): 2 validation errors for ChainOfThought
# steps
#   Field required [type=missing, input_value={'$schema': 'http://json-...ep', 'type': 'object'}}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# final_answer
#   Field required [type=missing, input_value={'$schema': 'http://json-...ep', 'type': 'object'}}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# Traceback (most recent call last):
#   File "/tmp/ipykernel_3371415/1813847204.py", line 158, in run
#     answer = ChainOfThought.model_validate_json(A_response)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/main.py", line 597, in model_validate_json
#     return cls.__pydantic_validator__.validate_json(json_data, strict=strict, context=context)
# pydantic_core._pydantic_core.ValidationError: 2 validation errors for ChainOfThought
# steps
#   Field required [type=missing, input_value={'$schema': 'http://json-...ep', 'type': 'object'}}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# final_answer
#   Field required [type=missing, input_value={'$schema': 'http://json-...ep', 'type': 'object'}}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 2024-12-02 18:07:25,995 - INFO - Generating answer for the question: What is the purpose of a gamma camera in obtaining images after the injection of a radiopharmaceutical? (attempt 2/3)
# 2024-12-02 18:07:31,260 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-02 18:07:31,262 - INFO - Generating answer for the question: What is the name of the most commonly used PET radionuclide? (attempt 1/3)
# 2024-12-02 18:07:33,977 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-02 18:07:33,979 - INFO - Generating answer for the question: What is the result of tissues that are actively metabolizing glucose after taking up fluorodeoxyglucose (FDG)? (attempt 1/3)
# 2024-12-02 18:07:40,153 - INFO - Question and answer successfully appended to the CSV file.
# complete chunks::  26%|██████▏                 | 26/100 [09:56<27:46, 22.53s/it]2024-12-02 18:07:40,155 - INFO - Generating questions for the current chunk...
# 2024-12-02 18:07:44,489 - ERROR - Error generating or validating questions (attempt 1/3): 1 validation error for QuestionSet
# questions
#   Field required [type=missing, input_value={'$schema': 'http://json-... 'required': ['text']}}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# Traceback (most recent call last):
#   File "/tmp/ipykernel_3371415/1813847204.py", line 139, in run
#     questions = QuestionSet.model_validate_json(Q_response)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/main.py", line 597, in model_validate_json
#     return cls.__pydantic_validator__.validate_json(json_data, strict=strict, context=context)
# pydantic_core._pydantic_core.ValidationError: 1 validation error for QuestionSet
# questions
#   Field required [type=missing, input_value={'$schema': 'http://json-... 'required': ['text']}}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 2024-12-02 18:07:44,490 - INFO - Generating questions for the current chunk...
# 2024-12-02 18:07:45,835 - INFO - Generating answer for the question: What is PET used for in cancer treatment? (attempt 1/3)
# 2024-12-02 18:07:54,141 - INFO - Question and answer successfully appended to the CSV file.
# ...
# 2024-12-02 18:30:06,792 - INFO - Generating answer for the question: What type of nerves do preganglionic parasympathetic fibers form in the sacral region? (attempt 1/3)
# 2024-12-02 18:30:09,566 - INFO - Question and answer successfully appended to the CSV file.
# complete chunks::  88%|█████████████████████   | 88/100 [32:26<04:28, 22.34s/it]2024-12-02 18:30:09,568 - INFO - Generating questions for the current chunk...
# 2024-12-02 18:30:15,752 - INFO - Generating answer for the question: Which cranial nerves (CN) do preganglionic parasympathetic motor fibers separate from to connect with ganglia? (attempt 1/3)
# 2024-12-02 18:30:21,022 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-02 18:30:21,023 - INFO - Generating answer for the question: What are the four distinct ganglia that house postganglionic motor neurons in the parasympathetic nervous system? (attempt 1/3)
# 2024-12-02 18:30:27,166 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-02 18:30:27,169 - INFO - Generating answer for the question: What is the primary function of the postganglionic parasympathetic neurons in the walls of the target viscera? (attempt 1/3)
# 2024-12-02 18:30:32,729 - INFO - Question and answer successfully appended to the CSV file.
# complete chunks::  89%|█████████████████████▎  | 89/100 [32:49<04:08, 22.58s/it]2024-12-02 18:30:32,732 - INFO - Generating questions for the current chunk...
# 2024-12-02 18:30:35,232 - INFO - Generating answer for the question: What is the typical entry point of visceral sensory fibers accompanying sympathetic fibers into the spinal cord? (attempt 1/3)
# 2024-12-02 18:30:46,442 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-02 18:30:46,443 - INFO - Generating answer for the question: Where do visceral sensory fibers in the IX nerve carry information from? (attempt 1/3)
# 2024-12-02 18:30:50,256 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-02 18:30:50,257 - INFO - Generating answer for the question: At what spinal cord levels do visceral sensory fibers from the heart typically enter? (attempt 1/3)
# 2024-12-02 18:30:53,696 - INFO - Question and answer successfully appended to the CSV file.
# complete chunks::  90%|█████████████████████▌  | 90/100 [33:10<03:40, 22.10s/it]2024-12-02 18:30:53,698 - INFO - Generating questions for the current chunk...
# 2024-12-02 18:31:00,325 - INFO - Generating answer for the question: What type of fibers in the enteric nervous system relay information to the CNS about the status of normal physiological processes and reflex activities? (attempt 1/3)
# 2024-12-02 18:31:04,953 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-02 18:31:04,955 - INFO - Generating answer for the question: Where are the visceral sensory fibers from pelvic viscera and the distal parts of the colon carried in the spinal cord? (attempt 1/3)
# 2024-12-02 18:31:07,856 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-02 18:31:07,857 - INFO - Generating answer for the question: What are the two interconnected plexuses found within the walls of the gastrointestinal tract? (attempt 1/3)
# 2024-12-02 18:31:19,375 - INFO - Question and answer successfully appended to the CSV file.
# complete chunks::  91%|█████████████████████▊  | 91/100 [33:36<03:28, 23.17s/it]2024-12-02 18:31:19,377 - INFO - Generating questions for the current chunk...
# 2024-12-02 18:31:20,947 - INFO - Generating answer for the question: Where are neurons in the enteric system derived from? (attempt 1/3)
# 2024-12-02 18:31:25,789 - ERROR - Error generating or validating answer (attempt 1/3): 2 validation errors for ChainOfThought
# steps
#   Field required [type=missing, input_value={'$schema': 'http://json-...red': ['explanation']}}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# final_answer
#   Field required [type=missing, input_value={'$schema': 'http://json-...red': ['explanation']}}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# Traceback (most recent call last):
#   File "/tmp/ipykernel_3371415/1813847204.py", line 158, in run
#     answer = ChainOfThought.model_validate_json(A_response)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/main.py", line 597, in model_validate_json
#     return cls.__pydantic_validator__.validate_json(json_data, strict=strict, context=context)
# pydantic_core._pydantic_core.ValidationError: 2 validation errors for ChainOfThought
# steps
#   Field required [type=missing, input_value={'$schema': 'http://json-...red': ['explanation']}}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# final_answer
#   Field required [type=missing, input_value={'$schema': 'http://json-...red': ['explanation']}}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 2024-12-02 18:31:25,790 - INFO - Generating answer for the question: Where are neurons in the enteric system derived from? (attempt 2/3)
# 2024-12-02 18:31:33,550 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-02 18:31:33,552 - INFO - Generating answer for the question: How many neurons are in the enteric system compared to the spinal cord? (attempt 1/3)
# 2024-12-02 18:31:42,762 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-02 18:31:42,764 - INFO - Generating answer for the question: What reflexes are regulated by sensory and motor neurons within the enteric system? (attempt 1/3)
# 2024-12-02 18:31:48,585 - INFO - Question and answer successfully appended to the CSV file.
# complete chunks::  92%|██████████████████████  | 92/100 [34:05<03:19, 24.98s/it]2024-12-02 18:31:48,587 - INFO - Generating questions for the current chunk...
# 2024-12-02 18:31:52,277 - INFO - Generating answer for the question: Which spinal nerves form the cervical plexus? (attempt 1/3)
# 2024-12-02 18:31:55,101 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-02 18:31:55,102 - INFO - Generating answer for the question: What is the primary function of the prevertebral plexus in the abdomen? (attempt 1/3)
# 2024-12-02 18:32:02,554 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-02 18:32:02,555 - INFO - Generating answer for the question: Which plexuses are formed in the thorax? (attempt 1/3)
# 2024-12-02 18:32:11,549 - INFO - Question and answer successfully appended to the CSV file.
# complete chunks::  93%|██████████████████████▎ | 93/100 [34:28<02:50, 24.38s/it]2024-12-02 18:32:11,551 - INFO - Generating questions for the current chunk...
# 2024-12-02 18:32:13,370 - INFO - Generating answer for the question: What are the anatomical planes discussed in the text? (attempt 1/3)
# 2024-12-02 18:32:16,795 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-02 18:32:16,796 - INFO - Generating answer for the question: What is the location of the inferior margin of the orbit in relation to the top of the external auditory meatus? (attempt 1/3)
# 2024-12-02 18:32:19,117 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-02 18:32:19,119 - INFO - Generating answer for the question: What type of imaging technology is used in the production of X-rays? (attempt 1/3)
# 2024-12-02 18:32:21,912 - INFO - Question and answer successfully appended to the CSV file.
# complete chunks::  94%|██████████████████████▌ | 94/100 [34:38<02:01, 20.17s/it]2024-12-02 18:32:21,914 - INFO - Generating questions for the current chunk...
# 2024-12-02 18:32:27,279 - INFO - Generating answer for the question: What type of scan is shown in Fig. 1.8? (attempt 1/3)
# 2024-12-02 18:32:30,679 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-02 18:32:30,680 - INFO - Generating answer for the question: What type of image is shown in Fig. 1.9? (attempt 1/3)
# 2024-12-02 18:32:36,023 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-02 18:32:36,024 - INFO - Generating answer for the question: What type of camera is shown in Fig. 1.11? (attempt 1/3)
# 2024-12-02 18:32:37,567 - INFO - Question and answer successfully appended to the CSV file.
# complete chunks::  95%|██████████████████████▊ | 95/100 [34:54<01:34, 18.82s/it]2024-12-02 18:32:37,569 - INFO - Generating questions for the current chunk...
# 2024-12-02 18:32:39,707 - INFO - Generating answer for the question: What is the age range of the patient in the developmental series of radiographs showing the ossification of carpal bones? (attempt 1/3)
# 2024-12-02 18:32:42,120 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-02 18:32:42,121 - INFO - Generating answer for the question: What is the type of marrow present in the vertebral bodies of the young patient in Fig. 1.15? (attempt 1/3)
# 2024-12-02 18:32:45,406 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-02 18:32:45,408 - INFO - Generating answer for the question: What type of fracture is shown in Fig. 1.16, and how is it treated? (attempt 1/3)
# 2024-12-02 18:32:50,890 - INFO - Question and answer successfully appended to the CSV file.
# complete chunks::  96%|███████████████████████ | 96/100 [35:07<01:08, 17.17s/it]2024-12-02 18:32:50,894 - INFO - Generating questions for the current chunk...
# 2024-12-02 18:32:52,119 - INFO - Generating answer for the question: What type of joint is the elbow joint? (attempt 1/3)
# 2024-12-02 18:32:55,906 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-02 18:32:55,908 - INFO - Generating answer for the question: What is the condition of the right femoral head? (attempt 1/3)
# 2024-12-02 18:33:00,057 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-02 18:33:00,058 - INFO - Generating answer for the question: What is the cause of wasting of the muscles supporting the hip? (attempt 1/3)
# 2024-12-02 18:33:03,063 - INFO - Question and answer successfully appended to the CSV file.
# complete chunks::  97%|███████████████████████▎| 97/100 [35:19<00:47, 15.67s/it]2024-12-02 18:33:03,065 - INFO - Generating questions for the current chunk...
# 2024-12-02 18:33:07,714 - INFO - Generating answer for the question: What is the condition shown in Fig. 1.23? (attempt 1/3)
# 2024-12-02 18:33:11,276 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-02 18:33:11,277 - INFO - Generating answer for the question: What type of imaging is used to show the muscle tear in the right adductor longus in Fig. 1.26? (attempt 1/3)
# 2024-12-02 18:33:15,038 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-02 18:33:15,039 - INFO - Generating answer for the question: What is the purpose of the radiograph in Fig. 1.24? (attempt 1/3)
# 2024-12-02 18:33:18,553 - INFO - Question and answer successfully appended to the CSV file.
# complete chunks::  98%|███████████████████████▌| 98/100 [35:35<00:31, 15.62s/it]2024-12-02 18:33:18,555 - INFO - Generating questions for the current chunk...
# 2024-12-02 18:33:23,827 - INFO - Generating answer for the question: What is the main function of lymphatic vessels? (attempt 1/3)
# 2024-12-02 18:33:26,374 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-02 18:33:26,376 - INFO - Generating answer for the question: Where are the axillary nodes located? (attempt 1/3)
# 2024-12-02 18:33:28,694 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-02 18:33:28,695 - INFO - Generating answer for the question: What is the primary role of the lymphatic system in relation to vascular capillary beds? (attempt 1/3)
# 2024-12-02 18:33:33,547 - ERROR - Error generating or validating answer (attempt 1/3): 2 validation errors for ChainOfThought
# steps
#   Field required [type=missing, input_value={'$schema': 'http://json-...ep', 'type': 'object'}}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# final_answer
#   Field required [type=missing, input_value={'$schema': 'http://json-...ep', 'type': 'object'}}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# Traceback (most recent call last):
#   File "/tmp/ipykernel_3371415/1813847204.py", line 158, in run
#     answer = ChainOfThought.model_validate_json(A_response)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/main.py", line 597, in model_validate_json
#     return cls.__pydantic_validator__.validate_json(json_data, strict=strict, context=context)
# pydantic_core._pydantic_core.ValidationError: 2 validation errors for ChainOfThought
# steps
#   Field required [type=missing, input_value={'$schema': 'http://json-...ep', 'type': 'object'}}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# final_answer
#   Field required [type=missing, input_value={'$schema': 'http://json-...ep', 'type': 'object'}}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 2024-12-02 18:33:33,549 - INFO - Generating answer for the question: What is the primary role of the lymphatic system in relation to vascular capillary beds? (attempt 2/3)
# 2024-12-02 18:33:38,406 - ERROR - Error generating or validating answer (attempt 2/3): 2 validation errors for ChainOfThought
# steps
#   Field required [type=missing, input_value={'$schema': 'http://json-...ep', 'type': 'object'}}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# final_answer
#   Field required [type=missing, input_value={'$schema': 'http://json-...ep', 'type': 'object'}}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# Traceback (most recent call last):
#   File "/tmp/ipykernel_3371415/1813847204.py", line 158, in run
#     answer = ChainOfThought.model_validate_json(A_response)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/main.py", line 597, in model_validate_json
#     return cls.__pydantic_validator__.validate_json(json_data, strict=strict, context=context)
# pydantic_core._pydantic_core.ValidationError: 2 validation errors for ChainOfThought
# steps
#   Field required [type=missing, input_value={'$schema': 'http://json-...ep', 'type': 'object'}}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# final_answer
#   Field required [type=missing, input_value={'$schema': 'http://json-...ep', 'type': 'object'}}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 2024-12-02 18:33:38,408 - INFO - Generating answer for the question: What is the primary role of the lymphatic system in relation to vascular capillary beds? (attempt 3/3)
# 2024-12-02 18:33:42,637 - INFO - Question and answer successfully appended to the CSV file.
# complete chunks::  99%|███████████████████████▊| 99/100 [35:59<00:18, 18.16s/it]2024-12-02 18:33:42,639 - INFO - Generating questions for the current chunk...
# 2024-12-02 18:33:48,105 - INFO - Generating answer for the question: What is the primary function of the lymphatic vessels shown in Fig. 1.30? (attempt 1/3)
# 2024-12-02 18:33:58,092 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-02 18:33:58,094 - INFO - Generating answer for the question: What is the condition of the patient in Fig. 1.31? (attempt 1/3)
# 2024-12-02 18:34:01,797 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-02 18:34:01,799 - INFO - Generating answer for the question: How do somatic sensory neurons develop from neural crest cells? (attempt 1/3)
# 2024-12-02 18:34:07,655 - INFO - Question and answer successfully appended to the CSV file.
# complete chunks:: 100%|███████████████████████| 100/100 [36:24<00:00, 21.84s/it]
# 2024-12-02 18:34:07,659 - INFO - Processing complete. Results are saved in the CSV file.

# %% [markdown]
# # raft with contextual chunk

# %%
import pandas as pd
raw_data = pd.read_csv('contextual_output.csv')
docs = raw_data.contextual_chunk.to_list()
num_questions = 3 
qa_data = run(docs[284:],num_questions)
print(raw_data.shape)
raw_data.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       3 docs = raw_data.contextual_chunk.to_list()
#       4 num_questions = 3
# ----> 5 qa_data = run(docs,num_questions)
#       6 print(raw_data.shape)
#       7 raw_data.head()
#
# NameError: name 'run' is not defined

# %%
docs[284:286]
# Out:
# ['The chunk is a description of the anterior wall of the thorax, specifically the sternum, ribs, and their articulations with the thoracic vertebrae and sternum.Anteriorly, the wall is made up of the sternum, which consists of the manubrium of sternum, body of sternum, and xiphoid process. The manubrium of sternum, angled posteriorly on the body of sternum at the manubriosternal joint, forms the sternal angle, which is a major surface landmark used by clinicians in performing physical examinations of the thorax. The anterior (distal) end of each rib is composed of costal cartilage, which contributes to the mobility and elasticity of the wall. All ribs articulate with thoracic vertebrae posteriorly. Most ribs (from rib II to IX) have three articulations with the vertebral column. The head of each rib articulates with the body of its own vertebra and with the body of the vertebra above (Fig. 3.2). As these ribs curve posteriorly, each also articulates with the transverse process of its vertebra. Anteriorly, the costal cartilages of ribs I to VII articulate with the sternum.',
#  'The provided chunk is a passage describing the anatomy of the thoracic wall, specifically the articulation of the costal cartilages with the sternum and the skeletal framework of the thoracic wall. It is situated within the document discussing various aspects of human anatomy, including the thorax, abdomen, and pelvic regions.Anteriorly, the costal cartilages of ribs I to VII articulate with the sternum. The costal cartilages of ribs VIII to X articulate with the inferior margins of the costal cartilages above them. Ribs XI and XII are called floating ribs because they do not articulate with other ribs, costal cartilages, or the sternum. Their costal cartilages are small, only covering their tips. The skeletal framework of the thoracic wall provides extensive attachment sites for muscles of the neck, abdomen, back, and upper limbs. A number of these muscles attach to ribs and function as accessory respiratory muscles; some of them also stabilize the position of the first and last ribs. Completely surrounded by skeletal elements, the superior thoracic aperture consists of the body of vertebra TI posteriorly, the medial margin of rib I on each side, and the manubrium anteriorly.']

# %%
# chunks = ["Anatomy includes those structures that can be seen grossly (without the aid of magnification) and microscopically (with the aid of magnification). Typically, when used by itself, the term anatomy tends to mean gross or macroscopic anatomy—that is, the study of structures that can be seen without using a microscopic. Microscopic anatomy, also called histology, is the study of cells and tissues using a microscope."]
num_questions = 3 
qa_data = run(docs,num_questions)
# Out:
# complete chunks::   0%|                                | 0/3017 [00:00<?, ?it/s]2024-12-09 12:38:47,229 - INFO - Generating questions for the current chunk...
# 2024-12-09 12:38:52,718 - ERROR - Error generating or validating questions (attempt 1/3): 1 validation error for QuestionSet
# questions
#   Field required [type=missing, input_value={'$schema': 'http://json-...nSet', 'type': 'object'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# Traceback (most recent call last):
#   File "/tmp/ipykernel_3534511/2693361454.py", line 180, in run
#     questions = QuestionSet.model_validate_json(Q_response)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/main.py", line 597, in model_validate_json
#     return cls.__pydantic_validator__.validate_json(json_data, strict=strict, context=context)
# pydantic_core._pydantic_core.ValidationError: 1 validation error for QuestionSet
# questions
#   Field required [type=missing, input_value={'$schema': 'http://json-...nSet', 'type': 'object'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 2024-12-09 12:38:52,721 - INFO - Generating questions for the current chunk...
# 2024-12-09 12:38:54,574 - INFO - Generating answer for the question: What is the primary focus of gross anatomy in the field of medicine? (attempt 1/3)
# 2024-12-09 12:39:01,433 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-09 12:39:01,436 - INFO - Generating answer for the question: What is the term for the study of cells and tissues using a microscope? (attempt 1/3)
# 2024-12-09 12:39:06,923 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-09 12:39:06,925 - INFO - Generating answer for the question: What is the role of anatomy in the practice of medicine? (attempt 1/3)
# 2024-12-09 12:39:11,028 - INFO - Question and answer successfully appended to the CSV file.
# complete chunks::   0%|                     | 1/3017 [00:23<19:56:20, 23.80s/it]2024-12-09 12:39:11,030 - INFO - Generating questions for the current chunk...
# 2024-12-09 12:39:15,183 - INFO - Generating answer for the question: What are the two primary techniques a student should use to learn anatomy? (attempt 1/3)
# 2024-12-09 12:39:18,272 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-09 12:39:18,273 - INFO - Generating answer for the question: How is anatomy more than just memorization of lists of names? (attempt 1/3)
# 2024-12-09 12:39:27,490 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-09 12:39:27,492 - INFO - Generating answer for the question: What is the key difference between knowing the names of the various branches of the external carotid artery and being able to visualize its course? (attempt 1/3)
# 2024-12-09 12:39:37,685 - INFO - Question and answer successfully appended to the CSV file.
# complete chunks::   0%|                     | 2/3017 [00:50<21:20:24, 25.48s/it]2024-12-09 12:39:37,687 - INFO - Generating questions for the current chunk...
# 2024-12-09 12:39:39,095 - INFO - Generating answer for the question: What is the Greek word that is the root of the term anatomy? (attempt 1/3)
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# 2024-12-09 12:39:41,672 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-09 12:39:41,674 - INFO - Generating answer for the question: What is the primary method of studying anatomy that involves cutting? (attempt 1/3)
# 2024-12-09 12:39:46,123 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-09 12:39:46,125 - INFO - Generating answer for the question: What is a learning aid that has replaced dissection in some cases? (attempt 1/3)
# 2024-12-09 12:39:51,041 - INFO - Question and answer successfully appended to the CSV file.
# complete chunks::   0%|                     | 3/3017 [01:03<16:41:51, 19.94s/it]2024-12-09 12:39:51,043 - INFO - Generating questions for the current chunk...
# 2024-12-09 12:39:53,096 - INFO - Generating answer for the question: What are the two main approaches to studying the human body in anatomy? (attempt 1/3)
# 2024-12-09 12:39:58,021 - ERROR - Error generating or validating answer (attempt 1/3): 2 validation errors for ChainOfThought
# steps
#   Field required [type=missing, input_value={'$schema': 'http://json-...ep', 'type': 'object'}}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# final_answer
#   Field required [type=missing, input_value={'$schema': 'http://json-...ep', 'type': 'object'}}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# Traceback (most recent call last):
#   File "/tmp/ipykernel_3534511/2693361454.py", line 204, in run
#     answer = ChainOfThought.model_validate_json(A_response)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/main.py", line 597, in model_validate_json
#     return cls.__pydantic_validator__.validate_json(json_data, strict=strict, context=context)
# pydantic_core._pydantic_core.ValidationError: 2 validation errors for ChainOfThought
# steps
#   Field required [type=missing, input_value={'$schema': 'http://json-...ep', 'type': 'object'}}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# final_answer
#   Field required [type=missing, input_value={'$schema': 'http://json-...ep', 'type': 'object'}}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 2024-12-09 12:39:58,023 - INFO - Generating answer for the question: What are the two main approaches to studying the human body in anatomy? (attempt 2/3)
# 2024-12-09 12:40:09,960 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-09 12:40:09,962 - INFO - Generating answer for the question: Which body region includes the vasculature, nerves, bones, muscles, and other structures and organs? (attempt 1/3)
# 2024-12-09 12:40:13,136 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-09 12:40:13,137 - INFO - Generating answer for the question: What is the primary focus of the cardiovascular system in the systemic approach to anatomy? (attempt 1/3)
# 2024-12-09 12:40:20,467 - INFO - Question and answer successfully appended to the CSV file.
# complete chunks::   0%|                     | 4/3017 [01:33<19:49:30, 23.69s/it]2024-12-09 12:40:20,470 - INFO - Generating questions for the current chunk...
# 2024-12-09 12:40:22,116 - INFO - Generating answer for the question: What is the benefit of the regional approach in studying anatomy when cadaver dissection is involved? (attempt 1/3)
# 2024-12-09 12:40:26,659 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-09 12:40:26,661 - INFO - Generating answer for the question: Which approach to studying anatomy is more suitable for understanding the continuity of an entire system throughout the body? (attempt 1/3)
# 2024-12-09 12:40:32,662 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-09 12:40:32,664 - INFO - Generating answer for the question: What is a limitation of the systemic approach in studying anatomy? (attempt 1/3)
# 2024-12-09 12:40:38,523 - INFO - Question and answer successfully appended to the CSV file.
# complete chunks::   0%|                     | 5/3017 [01:51<18:07:10, 21.66s/it]2024-12-09 12:40:38,526 - INFO - Generating questions for the current chunk...
# 2024-12-09 12:40:43,903 - INFO - Generating answer for the question: In the anatomical position, what is the orientation of the coronal planes? (attempt 1/3)
# 2024-12-09 12:40:50,039 - ERROR - Error generating or validating answer (attempt 1/3): 1 validation error for ChainOfThought
#   Invalid JSON: EOF while parsing an object at line 25 column 59 [type=json_invalid, input_value=' {\n  "steps": [\n    {\...e oriented vertically."', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.8/v/json_invalid
# Traceback (most recent call last):
#   File "/tmp/ipykernel_3534511/2693361454.py", line 204, in run
#     answer = ChainOfThought.model_validate_json(A_response)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/main.py", line 597, in model_validate_json
#     return cls.__pydantic_validator__.validate_json(json_data, strict=strict, context=context)
# pydantic_core._pydantic_core.ValidationError: 1 validation error for ChainOfThought
#   Invalid JSON: EOF while parsing an object at line 25 column 59 [type=json_invalid, input_value=' {\n  "steps": [\n    {\...e oriented vertically."', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.8/v/json_invalid
# 2024-12-09 12:40:50,041 - INFO - Generating answer for the question: In the anatomical position, what is the orientation of the coronal planes? (attempt 2/3)
# 2024-12-09 12:40:56,498 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-09 12:40:56,500 - INFO - Generating answer for the question: How are the hands positioned in the anatomical position? (attempt 1/3)
# 2024-12-09 12:41:02,182 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-09 12:41:02,183 - INFO - Generating answer for the question: What is the facial expression in the anatomical position? (attempt 1/3)
# 2024-12-09 12:41:04,577 - INFO - Question and answer successfully appended to the CSV file.
# complete chunks::   0%|                     | 6/3017 [02:17<19:21:50, 23.15s/it]2024-12-09 12:41:04,580 - INFO - Generating questions for the current chunk...
# 2024-12-09 12:41:08,360 - INFO - Generating answer for the question: What is the orientation of coronal planes? (attempt 1/3)
# 2024-12-09 12:41:11,420 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-09 12:41:11,421 - INFO - Generating answer for the question: Which two parts of the body are divided by the sagittal planes? (attempt 1/3)
# 2024-12-09 12:41:24,400 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-09 12:41:24,401 - INFO - Generating answer for the question: What is the term for the plane that passes through the center of the body? (attempt 1/3)
# 2024-12-09 12:41:29,516 - INFO - Question and answer successfully appended to the CSV file.
# complete chunks::   0%|                     | 7/3017 [02:42<19:50:45, 23.74s/it]2024-12-09 12:41:29,518 - INFO - Generating questions for the current chunk...
# 2024-12-09 12:41:31,432 - INFO - Generating answer for the question: What is the term for the position of structures relative to the median sagittal plane and the sides of the body? (attempt 1/3)
# 2024-12-09 12:41:37,266 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-09 12:41:37,267 - INFO - Generating answer for the question: What is the term for the position of structures relative to the "front" and "back" of the body? (attempt 1/3)
# 2024-12-09 12:41:41,484 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-09 12:41:41,486 - INFO - Generating answer for the question: What is the relationship between the nose and the eyes in terms of medial position? (attempt 1/3)
# 2024-12-09 12:41:44,696 - INFO - Question and answer successfully appended to the CSV file.
# complete chunks::   0%|                     | 8/3017 [02:57<17:33:45, 21.01s/it]2024-12-09 12:41:44,698 - INFO - Generating questions for the current chunk...
# 2024-12-09 12:41:48,824 - ERROR - Error generating or validating questions (attempt 1/3): 1 validation error for QuestionSet
# questions
#   Field required [type=missing, input_value={'$schema': 'http://json-...nSet', 'type': 'object'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# Traceback (most recent call last):
#   File "/tmp/ipykernel_3534511/2693361454.py", line 180, in run
#     questions = QuestionSet.model_validate_json(Q_response)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/main.py", line 597, in model_validate_json
#     return cls.__pydantic_validator__.validate_json(json_data, strict=strict, context=context)
# pydantic_core._pydantic_core.ValidationError: 1 validation error for QuestionSet
# questions
#   Field required [type=missing, input_value={'$schema': 'http://json-...nSet', 'type': 'object'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 2024-12-09 12:41:48,826 - INFO - Generating questions for the current chunk...
# 2024-12-09 12:41:50,689 - INFO - Generating answer for the question: What does the term'superior' refer to in the context of the body's vertical axis? (attempt 1/3)
# 2024-12-09 12:41:55,563 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-09 12:41:55,565 - INFO - Generating answer for the question: What is the difference between the terms 'proximal' and 'distal' in the context of the limbs? (attempt 1/3)
# 2024-12-09 12:41:59,213 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-09 12:41:59,214 - INFO - Generating answer for the question: What is the term 'cranial' used to describe in relation to the body? (attempt 1/3)
# 2024-12-09 12:42:03,681 - INFO - Question and answer successfully appended to the CSV file.
# complete chunks::   0%|                     | 9/3017 [03:16<17:01:38, 20.38s/it]2024-12-09 12:42:03,683 - INFO - Generating questions for the current chunk...
# 2024-12-09 12:42:08,056 - ERROR - Error generating or validating questions (attempt 1/3): 1 validation error for QuestionSet
# questions
#   Field required [type=missing, input_value={'$schema': 'http://json-...on', 'type': 'object'}}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# Traceback (most recent call last):
#   File "/tmp/ipykernel_3534511/2693361454.py", line 180, in run
#     questions = QuestionSet.model_validate_json(Q_response)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/main.py", line 597, in model_validate_json
#     return cls.__pydantic_validator__.validate_json(json_data, strict=strict, context=context)
# pydantic_core._pydantic_core.ValidationError: 1 validation error for QuestionSet
# questions
#   Field required [type=missing, input_value={'$schema': 'http://json-...on', 'type': 'object'}}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 2024-12-09 12:42:08,057 - INFO - Generating questions for the current chunk...
# 2024-12-09 12:42:13,534 - INFO - Generating answer for the question: What is the alternative term for the position of a structure toward the head? (attempt 1/3)
# 2024-12-09 12:42:18,648 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-09 12:42:18,649 - INFO - Generating answer for the question: What is the term used to describe the position of a structure with reference to the nose? (attempt 1/3)
# 2024-12-09 12:42:21,798 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-09 12:42:21,799 - INFO - Generating answer for the question: Which structure is superficial to the abdominal wall? (attempt 1/3)
# 2024-12-09 12:42:27,288 - INFO - Question and answer successfully appended to the CSV file.
# complete chunks::   0%|                    | 10/3017 [03:40<17:51:15, 21.38s/it]2024-12-09 12:42:27,290 - INFO - Generating questions for the current chunk...
# 2024-12-09 12:42:30,947 - INFO - Generating answer for the question: What are the structures included in the superficial region of the body? (attempt 1/3)
# 2024-12-09 12:42:40,049 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-09 12:42:40,051 - INFO - Generating answer for the question: What is the primary function of the deep fascia in the human body? (attempt 1/3)
# 2024-12-09 12:42:46,514 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-09 12:42:46,515 - INFO - Generating answer for the question: Who produced the first radiographic exposure of a human hand in 1895? (attempt 1/3)
# 2024-12-09 12:42:58,390 - INFO - Question and answer successfully appended to the CSV file.
# complete chunks::   0%|                    | 11/3017 [04:11<20:20:02, 24.35s/it]2024-12-09 12:42:58,392 - INFO - Generating questions for the current chunk...
# 2024-12-09 12:43:00,016 - INFO - Generating answer for the question: What is the purpose of collimating X-rays in X-ray technology? (attempt 1/3)
# 2024-12-09 12:43:07,416 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-09 12:43:07,418 - INFO - Generating answer for the question: What is the relationship between the type of tissue and the attenuation of X-rays in the human body? (attempt 1/3)
# 2024-12-09 12:43:11,308 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-09 12:43:11,309 - INFO - Generating answer for the question: How does the attenuation of X-rays result in differences in the X-ray image? (attempt 1/3)
# 2024-12-09 12:43:18,826 - INFO - Question and answer successfully appended to the CSV file.
# complete chunks::   0%|                    | 12/3017 [04:31<19:19:58, 23.16s/it]2024-12-09 12:43:18,829 - INFO - Generating questions for the current chunk...
# 2024-12-09 12:43:24,443 - INFO - Generating answer for the question: What is the main application of X-ray fluoroscopy in medical imaging? (attempt 1/3)
# 2024-12-09 12:43:28,953 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-09 12:43:28,954 - INFO - Generating answer for the question: What type of studies can be performed using X-ray fluoroscopy? (attempt 1/3)
# 2024-12-09 12:43:37,065 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-09 12:43:37,066 - INFO - Generating answer for the question: How is the X-ray tube modified to allow for real-time visualization in X-ray fluoroscopy? (attempt 1/3)
# 2024-12-09 12:43:42,363 - INFO - Question and answer successfully appended to the CSV file.
# complete chunks::   0%|                    | 13/3017 [04:55<19:25:16, 23.27s/it]2024-12-09 12:43:42,365 - INFO - Generating questions for the current chunk...
# 2024-12-09 12:43:47,888 - INFO - Generating answer for the question: What is the primary use of barium sulfate in gastrointestinal imaging? (attempt 1/3)
# 2024-12-09 12:43:53,848 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-09 12:43:53,849 - INFO - Generating answer for the question: What is the purpose of adding air to the barium sulfate suspension during a gastrointestinal examination? (attempt 1/3)
# 2024-12-09 12:44:00,982 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-09 12:44:00,983 - INFO - Generating answer for the question: Why is it important to use a nontoxic substance in gastrointestinal imaging? (attempt 1/3)
# 2024-12-09 12:44:11,389 - INFO - Question and answer successfully appended to the CSV file.
# complete chunks::   0%|                    | 14/3017 [05:24<20:51:51, 25.01s/it]2024-12-09 12:44:11,392 - INFO - Generating questions for the current chunk...
# 2024-12-09 12:44:17,463 - INFO - Generating answer for the question: What is the primary reason iodine-based molecules are used as contrast agents for intra-arterial and intravenous injections? (attempt 1/3)
# 2024-12-09 12:44:23,718 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-09 12:44:23,719 - INFO - Generating answer for the question: What are the potential risks associated with intra-arterial or intravenous injections of iodine-based contrast agents? (attempt 1/3)
# 2024-12-09 12:44:29,691 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-09 12:44:29,692 - INFO - Generating answer for the question: What additional benefit do iodine-based contrast agents provide in medical imaging, aside from visualizing arteries and veins? (attempt 1/3)
# 2024-12-09 12:44:33,978 - INFO - Question and answer successfully appended to the CSV file.
# complete chunks::   0%|                    | 15/3017 [05:46<20:14:52, 24.28s/it]2024-12-09 12:44:33,980 - INFO - Generating questions for the current chunk...
# 2024-12-09 12:44:35,522 - INFO - Generating answer for the question: What is the main challenge in visualizing blood vessels during angiography? (attempt 1/3)
# 2024-12-09 12:44:39,985 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-09 12:44:39,986 - INFO - Generating answer for the question: How does subtraction angiography address the challenge of visualizing blood vessels through bony structures? (attempt 1/3)
# 2024-12-09 12:44:49,324 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-09 12:44:49,325 - INFO - Generating answer for the question: What is the purpose of obtaining precontrast images in subtraction angiography? (attempt 1/3)
# 2024-12-09 12:44:57,542 - INFO - Question and answer successfully appended to the CSV file.
# complete chunks::   1%|                    | 16/3017 [06:10<20:03:40, 24.07s/it]2024-12-09 12:44:57,544 - INFO - Generating questions for the current chunk...
# 2024-12-09 12:45:02,899 - INFO - Generating answer for the question: What type of waves are used in ultrasonography? (attempt 1/3)
# 2024-12-09 12:45:06,431 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-09 12:45:06,434 - INFO - Generating answer for the question: How do piezoelectric materials contribute to ultrasonography? (attempt 1/3)
# 2024-12-09 12:45:18,272 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-09 12:45:18,274 - INFO - Generating answer for the question: What is displayed on the screen after interpreting the sound waves? (attempt 1/3)
# 2024-12-09 12:45:21,380 - INFO - Question and answer successfully appended to the CSV file.
# complete chunks::   1%|                    | 17/3017 [06:34<19:59:51, 24.00s/it]2024-12-09 12:45:21,382 - INFO - Generating questions for the current chunk...
# 2024-12-09 12:45:26,938 - INFO - Generating answer for the question: What is the primary use of ultrasound technology in pregnant women? (attempt 1/3)
# 2024-12-09 12:45:30,027 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-09 12:45:30,028 - INFO - Generating answer for the question: What is the common method for assessing the prostate in men with suspected prostate hypertrophy or malignancy? (attempt 1/3)
# 2024-12-09 12:45:33,069 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-09 12:45:33,070 - INFO - Generating answer for the question: What is the frequency range of the probes used in ultrasound technology? (attempt 1/3)
# 2024-12-09 12:45:38,278 - INFO - Question and answer successfully appended to the CSV file.
# complete chunks::   1%|                    | 18/3017 [06:51<18:12:50, 21.86s/it]2024-12-09 12:45:38,280 - INFO - Generating questions for the current chunk...
# 2024-12-09 12:45:43,777 - INFO - Generating answer for the question: What is the primary purpose of Doppler ultrasound in medical imaging? (attempt 1/3)
# 2024-12-09 12:45:48,443 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-09 12:45:48,444 - INFO - Generating answer for the question: Who invented Computed Tomography (CT) scans? (attempt 1/3)
# 2024-12-09 12:45:51,810 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-09 12:45:51,811 - INFO - Generating answer for the question: What is a consequence of obtaining precise measurements of blood flow and blood velocity using Doppler ultrasound? (attempt 1/3)
# 2024-12-09 12:45:54,993 - INFO - Question and answer successfully appended to the CSV file.
# complete chunks::   1%|▏                   | 19/3017 [07:07<16:55:11, 20.32s/it]2024-12-09 12:45:54,995 - INFO - Generating questions for the current chunk...
# 2024-12-09 12:45:56,483 - INFO - Generating answer for the question: What is the orientation of the images obtained by a CT scanner? (attempt 1/3)
# 2024-12-09 12:46:00,435 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-09 12:46:00,436 - INFO - Generating answer for the question: What is the function of the X-ray tube in a CT scanner? (attempt 1/3)
# 2024-12-09 12:46:04,850 - ERROR - Error generating or validating answer (attempt 1/3): 1 validation error for ChainOfThought
# steps.0.explanation
#   Field required [type=missing, input_value={'$ref': '#/$defs/Step'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# Traceback (most recent call last):
#   File "/tmp/ipykernel_3534511/2693361454.py", line 204, in run
#     answer = ChainOfThought.model_validate_json(A_response)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/main.py", line 597, in model_validate_json
#     return cls.__pydantic_validator__.validate_json(json_data, strict=strict, context=context)
# pydantic_core._pydantic_core.ValidationError: 1 validation error for ChainOfThought
# steps.0.explanation
#   Field required [type=missing, input_value={'$ref': '#/$defs/Step'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 2024-12-09 12:46:04,851 - INFO - Generating answer for the question: What is the function of the X-ray tube in a CT scanner? (attempt 2/3)
# 2024-12-09 12:46:11,773 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-09 12:46:11,774 - INFO - Generating answer for the question: What is the process that a computer performs on the images obtained by a CT scanner? (attempt 1/3)
# 2024-12-09 12:46:16,751 - INFO - Question and answer successfully appended to the CSV file.
# complete chunks::   1%|▏                   | 20/3017 [07:29<17:16:28, 20.75s/it]2024-12-09 12:46:16,753 - INFO - Generating questions for the current chunk...
# 2024-12-09 12:46:22,695 - INFO - Generating answer for the question: When was nuclear magnetic resonance imaging first described? (attempt 1/3)
# 2024-12-09 12:46:33,140 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-09 12:46:33,141 - INFO - Generating answer for the question: What is the primary component of biological tissues that is used in MRI? (attempt 1/3)
# 2024-12-09 12:46:38,074 - ERROR - Error generating or validating answer (attempt 1/3): 2 validation errors for ChainOfThought
# steps
#   Field required [type=missing, input_value={'$schema': 'http://json-...ep', 'type': 'object'}}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# final_answer
#   Field required [type=missing, input_value={'$schema': 'http://json-...ep', 'type': 'object'}}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# Traceback (most recent call last):
#   File "/tmp/ipykernel_3534511/2693361454.py", line 204, in run
#     answer = ChainOfThought.model_validate_json(A_response)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/main.py", line 597, in model_validate_json
#     return cls.__pydantic_validator__.validate_json(json_data, strict=strict, context=context)
# pydantic_core._pydantic_core.ValidationError: 2 validation errors for ChainOfThought
# steps
#   Field required [type=missing, input_value={'$schema': 'http://json-...ep', 'type': 'object'}}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# final_answer
#   Field required [type=missing, input_value={'$schema': 'http://json-...ep', 'type': 'object'}}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 2024-12-09 12:46:38,075 - INFO - Generating answer for the question: What is the primary component of biological tissues that is used in MRI? (attempt 2/3)
# 2024-12-09 12:46:41,189 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-09 12:46:41,190 - INFO - Generating answer for the question: What is the role of radio waves in the MRI process? (attempt 1/3)
# 2024-12-09 12:46:47,141 - INFO - Question and answer successfully appended to the CSV file.
# complete chunks::   1%|▏                   | 21/3017 [07:59<19:40:37, 23.64s/it]2024-12-09 12:46:47,145 - INFO - Generating questions for the current chunk...
# 2024-12-09 12:46:51,282 - INFO - Generating answer for the question: What type of images are obtained when the pulse sequence is altered to assess different properties of protons in MRI? (attempt 1/3)
# 2024-12-09 12:46:58,377 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-09 12:46:58,379 - INFO - Generating answer for the question: How do T1-weighted images typically display cerebrospinal fluid in the brain? (attempt 1/3)
# 2024-12-09 12:47:01,657 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-09 12:47:01,658 - INFO - Generating answer for the question: What type of imaging sequences can MRI use to assess flow within vessels? (attempt 1/3)
# 2024-12-09 12:47:06,625 - INFO - Question and answer successfully appended to the CSV file.
# complete chunks::   1%|▏                   | 22/3017 [08:19<18:37:53, 22.40s/it]2024-12-09 12:47:06,627 - INFO - Generating questions for the current chunk...
# 2024-12-09 12:47:07,980 - INFO - Generating answer for the question: What is the primary difference between gamma rays and X-rays in terms of their production? (attempt 1/3)
# 2024-12-09 12:47:12,974 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-09 12:47:12,975 - INFO - Generating answer for the question: How does MRI detect restricted diffusion in tissues? (attempt 1/3)
# 2024-12-09 12:47:26,057 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-09 12:47:26,058 - INFO - Generating answer for the question: What type of electromagnetic radiation is used in Nuclear Medicine imaging? (attempt 1/3)
# 2024-12-09 12:47:30,447 - INFO - Question and answer successfully appended to the CSV file.
# complete chunks::   1%|▏                   | 23/3017 [08:43<18:58:52, 22.82s/it]2024-12-09 12:47:30,449 - INFO - Generating questions for the current chunk...
# 2024-12-09 12:47:32,339 - INFO - Generating answer for the question: What is the primary difference between the production of X-rays and gamma rays in an atom? (attempt 1/3)
# 2024-12-09 12:47:36,871 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-09 12:47:36,872 - INFO - Generating answer for the question: What is required for an area to be visualized using gamma rays in medical imaging? (attempt 1/3)
# 2024-12-09 12:47:41,149 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-09 12:47:41,151 - INFO - Generating answer for the question: What is the desirable property of a gamma ray emitter in medical imaging to minimize harm to the patient? (attempt 1/3)
# 2024-12-09 12:47:46,091 - ERROR - Error generating or validating answer (attempt 1/3): 2 validation errors for ChainOfThought
# steps
#   Field required [type=missing, input_value={'$schema': 'http://json-...ep', 'type': 'object'}}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# final_answer
#   Field required [type=missing, input_value={'$schema': 'http://json-...ep', 'type': 'object'}}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# Traceback (most recent call last):
#   File "/tmp/ipykernel_3534511/2693361454.py", line 204, in run
#     answer = ChainOfThought.model_validate_json(A_response)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/main.py", line 597, in model_validate_json
#     return cls.__pydantic_validator__.validate_json(json_data, strict=strict, context=context)
# pydantic_core._pydantic_core.ValidationError: 2 validation errors for ChainOfThought
# steps
#   Field required [type=missing, input_value={'$schema': 'http://json-...ep', 'type': 'object'}}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# final_answer
#   Field required [type=missing, input_value={'$schema': 'http://json-...ep', 'type': 'object'}}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 2024-12-09 12:47:46,092 - INFO - Generating answer for the question: What is the desirable property of a gamma ray emitter in medical imaging to minimize harm to the patient? (attempt 2/3)
# 2024-12-09 12:47:50,548 - INFO - Question and answer successfully appended to the CSV file.
# complete chunks::   1%|▏                   | 24/3017 [09:03<18:17:45, 22.01s/it]2024-12-09 12:47:50,550 - INFO - Generating questions for the current chunk...
# 2024-12-09 12:47:54,475 - INFO - Generating answer for the question: What is the most commonly used radionuclide in radionuclide imaging? (attempt 1/3)
# 2024-12-09 12:47:57,857 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-09 12:47:57,858 - INFO - Generating answer for the question: What is the purpose of combining technetium-99m with methylene diphosphonate (MDP)? (attempt 1/3)
# 2024-12-09 12:48:04,348 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-09 12:48:04,349 - INFO - Generating answer for the question: How are images obtained after injection of the radiopharmaceutical? (attempt 1/3)
# 2024-12-09 12:48:07,502 - INFO - Question and answer successfully appended to the CSV file.
# complete chunks::   1%|▏                   | 25/3017 [09:20<17:01:47, 20.49s/it]2024-12-09 12:48:07,504 - INFO - Generating questions for the current chunk...
# 2024-12-09 12:48:09,088 - INFO - Generating answer for the question: What type of imaging modality is PET? (attempt 1/3)
# 2024-12-09 12:48:12,984 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-09 12:48:12,985 - INFO - Generating answer for the question: What is the primary purpose of using fluorodeoxyglucose (FDG) in PET imaging? (attempt 1/3)
# 2024-12-09 12:48:21,727 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-09 12:48:21,728 - INFO - Generating answer for the question: What is the role of a cyclotron in the production of PET radionuclides? (attempt 1/3)
# 2024-12-09 12:48:26,966 - INFO - Question and answer successfully appended to the CSV file.
# complete chunks::   1%|▏                   | 26/3017 [09:39<16:46:06, 20.18s/it]2024-12-09 12:48:26,969 - INFO - Generating questions for the current chunk...
# 2024-12-09 12:48:32,292 - INFO - Generating answer for the question: What is the primary purpose of using PET in cancer diagnosis? (attempt 1/3)
# 2024-12-09 12:48:36,814 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-09 12:48:36,815 - INFO - Generating answer for the question: How does SPECT detect disease conditions? (attempt 1/3)
# 2024-12-09 12:48:42,955 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-09 12:48:42,957 - INFO - Generating answer for the question: Why is it essential to understand the anatomy of the region being imaged? (attempt 1/3)
# 2024-12-09 12:48:47,432 - INFO - Question and answer successfully appended to the CSV file.
# complete chunks::   1%|▏                   | 27/3017 [10:00<16:50:00, 20.27s/it]2024-12-09 12:48:47,434 - INFO - Generating questions for the current chunk...
# 2024-12-09 12:48:50,066 - INFO - Generating answer for the question: What is the standard distance between the X-ray tube and the X-ray film in most instances, apart from chest radiography? (attempt 1/3)
# 2024-12-09 12:48:53,039 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-09 12:48:53,040 - INFO - Generating answer for the question: When positioning a patient for an anteroposterior (AP) radiograph, which part of the body is closest to the X-ray tube? (attempt 1/3)
# 2024-12-09 12:48:56,057 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-09 12:48:56,058 - INFO - Generating answer for the question: How is the orientation of the patient's body viewed when looking at a radiograph on a viewing box? (attempt 1/3)
# 2024-12-09 12:49:00,883 - INFO - Question and answer successfully appended to the CSV file.
# complete chunks::   1%|▏                   | 28/3017 [10:13<15:07:47, 18.22s/it]2024-12-09 12:49:00,885 - INFO - Generating questions for the current chunk...
# 2024-12-09 12:49:06,431 - INFO - Generating answer for the question: Why is it essential to take a chest radiograph with the patient erect? (attempt 1/3)
# 2024-12-09 12:49:13,343 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-09 12:49:13,345 - INFO - Generating answer for the question: What is the primary difference between a PA chest radiograph and an AP chest radiograph? (attempt 1/3)
# 2024-12-09 12:49:19,579 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-09 12:49:19,580 - INFO - Generating answer for the question: What should be checked for quality in a plain chest radiograph? (attempt 1/3)
# 2024-12-09 12:49:24,451 - INFO - Question and answer successfully appended to the CSV file.
# complete chunks::   1%|▏                   | 29/3017 [10:37<16:27:21, 19.83s/it]2024-12-09 12:49:24,454 - INFO - Generating questions for the current chunk...
# 2024-12-09 12:49:26,510 - INFO - Generating answer for the question: What is the position in which plain abdominal radiographs are obtained? (attempt 1/3)
# 2024-12-09 12:49:30,583 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-09 12:49:30,584 - INFO - Generating answer for the question: What is the position in which an erect plain abdominal radiograph is obtained when small bowel obstruction is suspected? (attempt 1/3)
# 2024-12-09 12:49:34,537 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-09 12:49:34,538 - INFO - Generating answer for the question: What is the purpose of using plain abdominal radiographs in the assessment of abdominal conditions? (attempt 1/3)
# 2024-12-09 12:49:40,572 - INFO - Question and answer successfully appended to the CSV file.
# complete chunks::   1%|▏                   | 30/3017 [10:53<15:31:39, 18.71s/it]2024-12-09 12:49:40,574 - INFO - Generating questions for the current chunk...
# 2024-12-09 12:49:42,336 - INFO - Generating answer for the question: What is the purpose of using a double-contrast barium enema in medical imaging? (attempt 1/3)
# 2024-12-09 12:49:49,787 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-09 12:49:49,788 - INFO - Generating answer for the question: What is the role of bowel preparation in a double-contrast barium enema procedure? (attempt 1/3)
# 2024-12-09 12:49:56,084 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-09 12:49:56,085 - INFO - Generating answer for the question: What is the effect of air insufflation in a double-contrast barium enema study? (attempt 1/3)
# 2024-12-09 12:50:02,792 - INFO - Question and answer successfully appended to the CSV file.
# complete chunks::   1%|▏                   | 31/3017 [11:15<16:23:41, 19.77s/it]2024-12-09 12:50:02,794 - INFO - Generating questions for the current chunk...
# 2024-12-09 12:50:05,083 - INFO - Generating answer for the question: What is the primary purpose of intravenous urography in medical imaging? (attempt 1/3)
# 2024-12-09 12:50:32,412 - ERROR - Error generating or validating answer (attempt 1/3): 1 validation error for ChainOfThought
#   Invalid JSON: EOF while parsing a string at line 15 column 102 [type=json_invalid, input_value=' {\n  "$defs": {\n    "S...stigation for assessing', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.8/v/json_invalid
# Traceback (most recent call last):
#   File "/tmp/ipykernel_3534511/2693361454.py", line 204, in run
#     answer = ChainOfThought.model_validate_json(A_response)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/main.py", line 597, in model_validate_json
#     return cls.__pydantic_validator__.validate_json(json_data, strict=strict, context=context)
# pydantic_core._pydantic_core.ValidationError: 1 validation error for ChainOfThought
#   Invalid JSON: EOF while parsing a string at line 15 column 102 [type=json_invalid, input_value=' {\n  "$defs": {\n    "S...stigation for assessing', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.8/v/json_invalid
# 2024-12-09 12:50:32,414 - INFO - Generating answer for the question: What is the primary purpose of intravenous urography in medical imaging? (attempt 2/3)
# 2024-12-09 12:50:39,268 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-09 12:50:39,269 - INFO - Generating answer for the question: How long after injection is the bladder expected to be full of contrast medium during an intravenous urography procedure? (attempt 1/3)
# 2024-12-09 12:50:47,221 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-09 12:50:47,222 - INFO - Generating answer for the question: What is the preferred term used by physicians for the imaging technique that uses computer-based X-ray tomography? (attempt 1/3)
# 2024-12-09 12:50:56,277 - INFO - Question and answer successfully appended to the CSV file.
# complete chunks::   1%|▏                   | 32/3017 [12:09<24:46:38, 29.88s/it]2024-12-09 12:50:56,280 - INFO - Generating questions for the current chunk...
# 2024-12-09 12:50:57,895 - INFO - Generating answer for the question: What is the preferred terminology used by physicians to refer to computed tomography? (attempt 1/3)
# 2024-12-09 12:51:01,362 - ERROR - Error generating or validating answer (attempt 1/3): 1 validation error for ChainOfThought
#   Invalid JSON: EOF while parsing an object at line 13 column 41 [type=json_invalid, input_value=' {\n    "steps": [\n    ...: "computed tomography"', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.8/v/json_invalid
# Traceback (most recent call last):
#   File "/tmp/ipykernel_3534511/2693361454.py", line 204, in run
#     answer = ChainOfThought.model_validate_json(A_response)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/main.py", line 597, in model_validate_json
#     return cls.__pydantic_validator__.validate_json(json_data, strict=strict, context=context)
# pydantic_core._pydantic_core.ValidationError: 1 validation error for ChainOfThought
#   Invalid JSON: EOF while parsing an object at line 13 column 41 [type=json_invalid, input_value=' {\n    "steps": [\n    ...: "computed tomography"', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.8/v/json_invalid
# 2024-12-09 12:51:01,363 - INFO - Generating answer for the question: What is the preferred terminology used by physicians to refer to computed tomography? (attempt 2/3)
# 2024-12-09 12:51:04,388 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-09 12:51:04,390 - INFO - Generating answer for the question: Why are patients often given oral and intravenous contrast media during a CT scan? (attempt 1/3)
# 2024-12-09 12:51:09,614 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-09 12:51:09,616 - INFO - Generating answer for the question: What is the benefit of obtaining images early after intravenous contrast injection during a CT scan? (attempt 1/3)
# 2024-12-09 12:51:16,785 - INFO - Question and answer successfully appended to the CSV file.
# complete chunks::   1%|▏                   | 33/3017 [12:29<22:26:16, 27.07s/it]2024-12-09 12:51:16,788 - INFO - Generating questions for the current chunk...
# 2024-12-09 12:51:18,185 - INFO - Generating answer for the question: What is the main advantage of CT scanning in visualizing the body? (attempt 1/3)
# 2024-12-09 12:51:22,471 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-09 12:51:22,472 - INFO - Generating answer for the question: How do MRI images help in understanding the brain and its coverings? (attempt 1/3)
# 2024-12-09 12:51:28,777 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-09 12:51:28,778 - INFO - Generating answer for the question: What type of substances are typically used in MRI contrast agents? (attempt 1/3)
# 2024-12-09 12:51:35,083 - INFO - Question and answer successfully appended to the CSV file.
# complete chunks::   1%|▏                   | 34/3017 [12:47<20:14:58, 24.44s/it]2024-12-09 12:51:35,085 - INFO - Generating questions for the current chunk...
# 2024-12-09 12:51:37,707 - INFO - Generating answer for the question: What is the primary purpose of most nuclear medicine images? (attempt 1/3)
# 2024-12-09 12:51:40,547 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-09 12:51:40,548 - INFO - Generating answer for the question: What is the expected dose of radiation given to a patient during an X-ray or nuclear medicine investigation? (attempt 1/3)
# 2024-12-09 12:51:46,989 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-09 12:51:46,990 - INFO - Generating answer for the question: What is the role of laws in regulating radiation exposure for medical procedures? (attempt 1/3)
# 2024-12-09 12:51:52,564 - INFO - Question and answer successfully appended to the CSV file.
# complete chunks::   1%|▏                   | 35/3017 [13:05<18:30:50, 22.35s/it]2024-12-09 12:51:52,566 - INFO - Generating questions for the current chunk...
# 2024-12-09 12:51:57,978 - INFO - Generating answer for the question: What is the primary benefit of using ultrasound imaging for assessing the fetus? (attempt 1/3)
# 2024-12-09 12:52:04,616 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-09 12:52:04,617 - INFO - Generating answer for the question: What are the two subgroups of the skeletal system? (attempt 1/3)
# 2024-12-09 12:52:09,549 - ERROR - Error generating or validating answer (attempt 1/3): 2 validation errors for ChainOfThought
# steps
#   Field required [type=missing, input_value={'$schema': 'http://json-...ep', 'type': 'object'}}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# final_answer
#   Field required [type=missing, input_value={'$schema': 'http://json-...ep', 'type': 'object'}}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# Traceback (most recent call last):
#   File "/tmp/ipykernel_3534511/2693361454.py", line 204, in run
#     answer = ChainOfThought.model_validate_json(A_response)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/main.py", line 597, in model_validate_json
#     return cls.__pydantic_validator__.validate_json(json_data, strict=strict, context=context)
# pydantic_core._pydantic_core.ValidationError: 2 validation errors for ChainOfThought
# steps
#   Field required [type=missing, input_value={'$schema': 'http://json-...ep', 'type': 'object'}}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# final_answer
#   Field required [type=missing, input_value={'$schema': 'http://json-...ep', 'type': 'object'}}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 2024-12-09 12:52:09,551 - INFO - Generating answer for the question: What are the two subgroups of the skeletal system? (attempt 2/3)
# 2024-12-09 12:52:17,632 - ERROR - Error generating or validating answer (attempt 2/3): 1 validation error for ChainOfThought
#   Invalid JSON: EOF while parsing an object at line 46 column 124 [type=json_invalid, input_value=' {\n  "$defs": {\n    "S...appendicular skeleton."', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.8/v/json_invalid
# Traceback (most recent call last):
#   File "/tmp/ipykernel_3534511/2693361454.py", line 204, in run
#     answer = ChainOfThought.model_validate_json(A_response)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/main.py", line 597, in model_validate_json
#     return cls.__pydantic_validator__.validate_json(json_data, strict=strict, context=context)
# pydantic_core._pydantic_core.ValidationError: 1 validation error for ChainOfThought
# ...
#     answer = ChainOfThought.model_validate_json(A_response)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/main.py", line 597, in model_validate_json
#     return cls.__pydantic_validator__.validate_json(json_data, strict=strict, context=context)
# pydantic_core._pydantic_core.ValidationError: 2 validation errors for ChainOfThought
# steps
#   Field required [type=missing, input_value={'$schema': 'http://json-...ep', 'type': 'object'}}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# final_answer
#   Field required [type=missing, input_value={'$schema': 'http://json-...ep', 'type': 'object'}}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 2024-12-09 14:18:19,532 - INFO - Generating answer for the question: What is the primary function of the intercostal muscles? (attempt 2/3)
# 2024-12-09 14:18:26,573 - INFO - Question and answer successfully appended to the CSV file.
# 2024-12-09 14:18:26,574 - INFO - Generating answer for the question: What is the main structure that forms the anterior component of the thoracic wall? (attempt 1/3)
# 2024-12-09 14:18:32,708 - INFO - Question and answer successfully appended to the CSV file.
# complete chunks::   9%|█▌               | 284/3017 [1:39:45<16:51:04, 22.20s/it]2024-12-09 14:18:32,710 - INFO - Generating questions for the current chunk...
# 2024-12-09 14:18:36,767 - ERROR - Error generating or validating questions (attempt 1/3): 1 validation error for QuestionSet
# questions
#   Field required [type=missing, input_value={'$schema': 'http://json-...nSet', 'type': 'object'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# Traceback (most recent call last):
#   File "/tmp/ipykernel_3534511/2693361454.py", line 180, in run
#     questions = QuestionSet.model_validate_json(Q_response)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/main.py", line 597, in model_validate_json
#     return cls.__pydantic_validator__.validate_json(json_data, strict=strict, context=context)
# pydantic_core._pydantic_core.ValidationError: 1 validation error for QuestionSet
# questions
#   Field required [type=missing, input_value={'$schema': 'http://json-...nSet', 'type': 'object'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 2024-12-09 14:18:36,769 - INFO - Generating questions for the current chunk...
# complete chunks::   9%|█▌               | 284/3017 [1:39:53<16:01:14, 21.10s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 3
#       1 # chunks = ["Anatomy includes those structures that can be seen grossly (without the aid of magnification) and microscopically (with the aid of magnification). Typically, when used by itself, the term anatomy tends to mean gross or macroscopic anatomy—that is, the study of structures that can be seen without using a microscopic. Microscopic anatomy, also called histology, is the study of cells and tissues using a microscope."]
#       2 num_questions = 3
# ----> 3 qa_data = run(docs,num_questions)
#
# Cell In[1], line 178, in run(chunks, num_questions)
#     176 try:
#     177     logger.info("Generating questions for the current chunk...")
# --> 178     Q_response = generate_content(Q_gen_template_prompt(chunk, num_questions, q_schema), 512)
#     179     logger.debug(f"Q_response: {Q_response}")
#     180     questions = QuestionSet.model_validate_json(Q_response)
#
# Cell In[1], line 66, in generate_content(prompt, max_new_tokens)
#      65 def generate_content(prompt: str, max_new_tokens: int) -> str:
# ---> 66     outputs = pipeline(
#      67         prompt,
#      68         max_new_tokens=max_new_tokens,
#      69         return_full_text=False,
#      70     )
#      71     return outputs[0]["generated_text"]
#
# File ~/.local/lib/python3.10/site-packages/transformers/pipelines/text_generation.py:272, in TextGenerationPipeline.__call__(self, text_inputs, **kwargs)
#     270         return super().__call__(chats, **kwargs)
#     271 else:
# --> 272     return super().__call__(text_inputs, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/transformers/pipelines/base.py:1302, in Pipeline.__call__(self, inputs, num_workers, batch_size, *args, **kwargs)
#    1294     return next(
#    1295         iter(
#    1296             self.get_iterator(
#    (...)
#    1299         )
#    1300     )
#    1301 else:
# -> 1302     return self.run_single(inputs, preprocess_params, forward_params, postprocess_params)
#
# File ~/.local/lib/python3.10/site-packages/transformers/pipelines/base.py:1309, in Pipeline.run_single(self, inputs, preprocess_params, forward_params, postprocess_params)
#    1307 def run_single(self, inputs, preprocess_params, forward_params, postprocess_params):
#    1308     model_inputs = self.preprocess(inputs, **preprocess_params)
# -> 1309     model_outputs = self.forward(model_inputs, **forward_params)
#    1310     outputs = self.postprocess(model_outputs, **postprocess_params)
#    1311     return outputs
#
# File ~/.local/lib/python3.10/site-packages/transformers/pipelines/base.py:1209, in Pipeline.forward(self, model_inputs, **forward_params)
#    1207     with inference_context():
#    1208         model_inputs = self._ensure_tensor_on_device(model_inputs, device=self.device)
# -> 1209         model_outputs = self._forward(model_inputs, **forward_params)
#    1210         model_outputs = self._ensure_tensor_on_device(model_outputs, device=torch.device("cpu"))
#    1211 else:
#
# File ~/.local/lib/python3.10/site-packages/transformers/pipelines/text_generation.py:370, in TextGenerationPipeline._forward(self, model_inputs, **generate_kwargs)
#     367 if "generation_config" not in generate_kwargs:
#     368     generate_kwargs["generation_config"] = self.generation_config
# --> 370 generated_sequence = self.model.generate(input_ids=input_ids, attention_mask=attention_mask, **generate_kwargs)
#     371 out_b = generated_sequence.shape[0]
#     372 if self.framework == "pt":
#
# File /usr/local/lib/python3.10/dist-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/transformers/generation/utils.py:2215, in GenerationMixin.generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, **kwargs)
#    2207     input_ids, model_kwargs = self._expand_inputs_for_generation(
#    2208         input_ids=input_ids,
#    2209         expand_size=generation_config.num_return_sequences,
#    2210         is_encoder_decoder=self.config.is_encoder_decoder,
#    2211         **model_kwargs,
#    2212     )
#    2214     # 12. run sample (it degenerates to greedy search when `generation_config.do_sample=False`)
# -> 2215     result = self._sample(
#    2216         input_ids,
#    2217         logits_processor=prepared_logits_processor,
#    2218         stopping_criteria=prepared_stopping_criteria,
#    2219         generation_config=generation_config,
#    2220         synced_gpus=synced_gpus,
#    2221         streamer=streamer,
#    2222         **model_kwargs,
#    2223     )
#    2225 elif generation_mode in (GenerationMode.BEAM_SAMPLE, GenerationMode.BEAM_SEARCH):
#    2226     # 11. prepare beam search scorer
#    2227     beam_scorer = BeamSearchScorer(
#    2228         batch_size=batch_size,
#    2229         num_beams=generation_config.num_beams,
#    (...)
#    2234         max_length=generation_config.max_length,
#    2235     )
#
# File ~/.local/lib/python3.10/site-packages/transformers/generation/utils.py:3206, in GenerationMixin._sample(self, input_ids, logits_processor, stopping_criteria, generation_config, synced_gpus, streamer, **model_kwargs)
#    3203 model_inputs.update({"output_hidden_states": output_hidden_states} if output_hidden_states else {})
#    3205 # forward pass to get next token
# -> 3206 outputs = self(**model_inputs, return_dict=True)
#    3208 # synced_gpus: don't waste resources running the code we don't need; kwargs must be updated before skipping
#    3209 model_kwargs = self._update_model_kwargs_for_generation(
#    3210     outputs,
#    3211     model_kwargs,
#    3212     is_encoder_decoder=self.config.is_encoder_decoder,
#    3213 )
#
# File /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/.local/lib/python3.10/site-packages/transformers/models/llama/modeling_llama.py:1190, in LlamaForCausalLM.forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict, cache_position, num_logits_to_keep, **loss_kwargs)
#    1187 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
#    1189 # decoder outputs consists of (dec_features, layer_state, dec_hidden, dec_attn)
# -> 1190 outputs = self.model(
#    1191     input_ids=input_ids,
#    1192     attention_mask=attention_mask,
#    1193     position_ids=position_ids,
#    1194     past_key_values=past_key_values,
#    1195     inputs_embeds=inputs_embeds,
#    1196     use_cache=use_cache,
#    1197     output_attentions=output_attentions,
#    1198     output_hidden_states=output_hidden_states,
#    1199     return_dict=return_dict,
#    1200     cache_position=cache_position,
#    1201 )
#    1203 hidden_states = outputs[0]
#    1204 if self.config.pretraining_tp > 1:
#
# File /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/.local/lib/python3.10/site-packages/transformers/models/llama/modeling_llama.py:945, in LlamaModel.forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict, cache_position)
#     933     layer_outputs = self._gradient_checkpointing_func(
#     934         decoder_layer.__call__,
#     935         hidden_states,
#    (...)
#     942         position_embeddings,
#     943     )
#     944 else:
# --> 945     layer_outputs = decoder_layer(
#     946         hidden_states,
#     947         attention_mask=causal_mask,
#     948         position_ids=position_ids,
#     949         past_key_value=past_key_values,
#     950         output_attentions=output_attentions,
#     951         use_cache=use_cache,
#     952         cache_position=cache_position,
#     953         position_embeddings=position_embeddings,
#     954     )
#     956 hidden_states = layer_outputs[0]
#     958 if use_cache:
#
# File /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/.local/lib/python3.10/site-packages/transformers/models/llama/modeling_llama.py:676, in LlamaDecoderLayer.forward(self, hidden_states, attention_mask, position_ids, past_key_value, output_attentions, use_cache, cache_position, position_embeddings, **kwargs)
#     673 hidden_states = self.input_layernorm(hidden_states)
#     675 # Self Attention
# --> 676 hidden_states, self_attn_weights, present_key_value = self.self_attn(
#     677     hidden_states=hidden_states,
#     678     attention_mask=attention_mask,
#     679     position_ids=position_ids,
#     680     past_key_value=past_key_value,
#     681     output_attentions=output_attentions,
#     682     use_cache=use_cache,
#     683     cache_position=cache_position,
#     684     position_embeddings=position_embeddings,
#     685     **kwargs,
#     686 )
#     687 hidden_states = residual + hidden_states
#     689 # Fully Connected
#
# File /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/.local/lib/python3.10/site-packages/transformers/models/llama/modeling_llama.py:602, in LlamaSdpaAttention.forward(self, hidden_states, attention_mask, position_ids, past_key_value, output_attentions, use_cache, cache_position, position_embeddings, **kwargs)
#     598 # We dispatch to SDPA's Flash Attention or Efficient kernels via this `is_causal` if statement instead of an inline conditional assignment
#     599 # in SDPA to support both torch.compile's dynamic shapes and full graph options. An inline conditional prevents dynamic shapes from compiling.
#     600 is_causal = True if causal_mask is None and q_len > 1 else False
# --> 602 attn_output = torch.nn.functional.scaled_dot_product_attention(
#     603     query_states,
#     604     key_states,
#     605     value_states,
#     606     attn_mask=causal_mask,
#     607     dropout_p=self.attention_dropout if self.training else 0.0,
#     608     is_causal=is_causal,
#     609 )
#     611 attn_output = attn_output.transpose(1, 2).contiguous()
#     612 attn_output = attn_output.view(bsz, q_len, -1)
#
# KeyboardInterrupt:
